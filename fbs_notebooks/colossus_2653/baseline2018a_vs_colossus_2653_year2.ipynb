# %%
from __future__ import print_function
import lsst.sims.maf.plots as plots
import warnings
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import lsst.sims.maf.metricBundles as mb
import lsst.sims.maf.plots as plots
import lsst.sims.maf.runComparison as rc
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fe4257f0-ed0e-4c2b-b16c-706ea61184c7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Setup

# %%
colors = {'baseline2018a':'b','colossus_2653': 'r'}
runlist = list(colors.keys())

# %%
comp = rc.RunComparison(baseDir='.',runlist=runlist)

# %%
all_dict = comp.buildMetricDict(subdir='all02')

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(all_dict)

# %%
df_list = []

# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format

# %%
nvists = comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Fraction of total Nvisits All props night <= 730            0.191
# Nvisits All props night <= 730                         453105.000
# Max Nvisits All props night <= 730 OneDSlicer            1081.000
# Mean Nvisits All props night <= 730 OneDSlicer            774.538
# Median Nvisits All props night <= 730 OneDSlicer          773.000
# Min Nvisits All props night <= 730 OneDSlicer             181.000
# N(+3Sigma) Nvisits All props night <= 730 OneDS...          0.000
# N(-3Sigma) Nvisits All props night <= 730 OneDS...          3.000
# Nvisits All props night <= 730 OneDSlicer                 585.000
# Rms Nvisits All props night <= 730 OneDSlicer             184.084
#
#                                                     colossus_2653
# Fraction of total Nvisits All props night <= 730            0.939
# Nvisits All props night <= 730                         423573.000
# Max Nvisits All props night <= 730 OneDSlicer            1008.000
# Mean Nvisits All props night <= 730 OneDSlicer            724.056
# Median Nvisits All props night <= 730 OneDSlicer          742.000
# Min Nvisits All props night <= 730 OneDSlicer             179.000
# N(+3Sigma) Nvisits All props night <= 730 OneDS...          0.000
# N(-3Sigma) Nvisits All props night <= 730 OneDS...         14.000
# Nvisits All props night <= 730 OneDSlicer                 585.000
# Rms Nvisits All props night <= 730 OneDSlicer             160.021

# %%
from tabulate import tabulate

# %%
print(tabulate(nvists[runlist], tablefmt="pipe", headers="keys"))
# Out:
# |                                                      |   baseline2018a |   colossus_2653 |
# |:-----------------------------------------------------|----------------:|----------------:|
# | Fraction of total Nvisits All props night <= 730     |        0.190966 |        0.939055 |
# | Nvisits All props night <= 730                       |   453105        |   423573        |
# | Max Nvisits All props night <= 730 OneDSlicer        |     1081        |     1008        |
# | Mean Nvisits All props night <= 730 OneDSlicer       |      774.538    |      724.056    |
# | Median Nvisits All props night <= 730 OneDSlicer     |      773        |      742        |
# | Min Nvisits All props night <= 730 OneDSlicer        |      181        |      179        |
# | N(+3Sigma) Nvisits All props night <= 730 OneDSlicer |        0        |        0        |
# | N(-3Sigma) Nvisits All props night <= 730 OneDSlicer |        3        |       14        |
# | Nvisits All props night <= 730 OneDSlicer            |      585        |      585        |
# | Rms Nvisits All props night <= 730 OneDSlicer        |      184.084    |      160.021    |

# %% [markdown]
# # Fraction of Total visits per proposal

# %%
comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Fraction of total Nvisits DeepDrillingCosmology...          0.008
# Fraction of total Nvisits WideFastDeep night <=...          0.165
# Fraction of total Nvisits NorthEclipticSpur nig...          0.010
# Fraction of total Nvisits GalacticPlane night <...          0.004
# Fraction of total Nvisits WFD night <= 730                  0.165
# Fraction of total Nvisits All props night <= 730            0.191
# Fraction of total Nvisits SouthCelestialPole ni...          0.004
# Fraction of total Nvisits DD night <= 730                   0.008
#
#                                                     colossus_2653
# Fraction of total Nvisits DeepDrillingCosmology...          0.056
# Fraction of total Nvisits WideFastDeep night <=...          0.787
# Fraction of total Nvisits NorthEclipticSpur nig...          0.039
# Fraction of total Nvisits GalacticPlane night <...          0.018
# Fraction of total Nvisits WFD night <= 730                  0.787
# Fraction of total Nvisits All props night <= 730            0.939
# Fraction of total Nvisits SouthCelestialPole ni...          0.040
# Fraction of total Nvisits DD night <= 730                   0.056

# %% [markdown]
# # Median Nvsits per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median NVisits WFD night < 730 u band HealpixSl...         11.000
# Median NVisits WFD night < 730 i band HealpixSl...         31.000
# Median NVisits WFD night < 730 z band HealpixSl...         47.000
# Median NVisits WFD night < 730 y band HealpixSl...         43.000
# Median NVisits WFD night < 730 all bands Healpi...        176.000
# Median NVisits WFD night < 730 r band HealpixSl...         33.000
# Median NVisits WFD night < 730 g band HealpixSl...         14.000
#
#                                                     colossus_2653
# Median NVisits WFD night < 730 u band HealpixSl...         15.000
# Median NVisits WFD night < 730 i band HealpixSl...         37.000
# Median NVisits WFD night < 730 z band HealpixSl...         33.000
# Median NVisits WFD night < 730 y band HealpixSl...         54.000
# Median NVisits WFD night < 730 all bands Healpi...        188.000
# Median NVisits WFD night < 730 r band HealpixSl...         36.000
# Median NVisits WFD night < 730 g band HealpixSl...         12.000

# %% [markdown]
# # Median CoaddedM5 per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median CoaddM5 WFD night < 730 u band HealpixSl...         24.694
# Median CoaddM5 WFD night < 730 i band HealpixSl...         25.600
# Median CoaddM5 WFD night < 730 z band HealpixSl...         25.003
# Median CoaddM5 WFD night < 730 y band HealpixSl...         24.174
# Median CoaddM5 WFD night < 730 r band HealpixSl...         26.231
# Median CoaddM5 WFD night < 730 g band HealpixSl...         26.124
#
#                                                     colossus_2653
# Median CoaddM5 WFD night < 730 u band HealpixSl...         24.928
# Median CoaddM5 WFD night < 730 i band HealpixSl...         25.672
# Median CoaddM5 WFD night < 730 z band HealpixSl...         24.950
# Median CoaddM5 WFD night < 730 y band HealpixSl...         24.255
# Median CoaddM5 WFD night < 730 r band HealpixSl...         26.154
# Median CoaddM5 WFD night < 730 g band HealpixSl...         25.950

# %% [markdown]
# # Median seeingEff per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median Median seeingEff WFD night < 730 u band ...          0.924
# Median Median seeingEff WFD night < 730 i band ...          0.825
# Median Median seeingEff WFD night < 730 z band ...          0.798
# Median Median seeingEff WFD night < 730 y band ...          0.789
# Median Median seeingEff WFD night < 730 all ban...          0.822
# Median Median seeingEff WFD night < 730 r band ...          0.858
# Median Median seeingEff WFD night < 730 g band ...          0.912
#
#                                                     colossus_2653
# Median Median seeingEff WFD night < 730 u band ...          0.883
# Median Median seeingEff WFD night < 730 i band ...          0.813
# Median Median seeingEff WFD night < 730 z band ...          0.810
# Median Median seeingEff WFD night < 730 y band ...          0.794
# Median Median seeingEff WFD night < 730 all ban...          0.820
# Median Median seeingEff WFD night < 730 r band ...          0.847
# Median Median seeingEff WFD night < 730 g band ...          0.894

# %% [markdown]
# # Median airmass

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median Median airmass WFD night < 730 u band He...          1.043
# Median Median airmass WFD night < 730 i band He...          1.047
# Median Median airmass WFD night < 730 z band He...          1.056
# Median Median airmass WFD night < 730 y band He...          1.053
# Median Median airmass WFD night < 730 all bands...          1.045
# Median Median airmass WFD night < 730 r band He...          1.045
# Median Median airmass WFD night < 730 g band He...          1.046
#
#                                                     colossus_2653
# Median Median airmass WFD night < 730 u band He...          1.054
# Median Median airmass WFD night < 730 i band He...          1.047
# Median Median airmass WFD night < 730 z band He...          1.048
# Median Median airmass WFD night < 730 y band He...          1.056
# Median Median airmass WFD night < 730 all bands...          1.050
# Median Median airmass WFD night < 730 r band He...          1.048
# Median Median airmass WFD night < 730 g band He...          1.049

# %% [markdown]
# # Slew statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='slew',axis=0).dropna())
comp.summaryStats.T.filter(like='slew',axis=0).dropna()
# Out:
#                             baseline2018a  colossus_2653
# Mean slewTime All visits            8.139         11.079
# Median slewTime All visits          5.300          5.379
# Min slewTime All visits             2.000          2.000
# Max slewTime All visits           142.959        140.000

# %% [markdown]
# # Filter change statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='Filter',axis=0).dropna())
comp.summaryStats.T.filter(like='Filter',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Filter Changes Whole Survey night <= 730                 1723.000
# Filter Changes Per Night night <= 730 OneDSlicer          585.000
# Max Filter Changes Per Night night <= 730 OneDS...         23.000
# Mean Filter Changes Per Night night <= 730 OneD...          2.643
# Median Filter Changes Per Night night <= 730 On...          2.000
# Min Filter Changes Per Night night <= 730 OneDS...          0.000
# N(+3Sigma) Filter Changes Per Night night <= 73...         10.000
# N(-3Sigma) Filter Changes Per Night night <= 73...          0.000
# Rms Filter Changes Per Night night <= 730 OneDS...          3.255
#
#                                                     colossus_2653
# Filter Changes Whole Survey night <= 730                 2375.000
# Filter Changes Per Night night <= 730 OneDSlicer          585.000
# Max Filter Changes Per Night night <= 730 OneDS...          8.000
# Mean Filter Changes Per Night night <= 730 OneD...          3.075
# Median Filter Changes Per Night night <= 730 On...          2.000
# Min Filter Changes Per Night night <= 730 OneDS...          0.000
# N(+3Sigma) Filter Changes Per Night night <= 73...          0.000
# N(-3Sigma) Filter Changes Per Night night <= 73...          0.000
# Rms Filter Changes Per Night night <= 730 OneDS...          2.574

# %% [markdown]
# # Normalized effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Normalized Teff WFD night < 730 all bands',axis=0).dropna())
comp.summaryStats.T.filter(like='Normalized Teff WFD night < 730 all bands',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Normalized Teff WFD night < 730 all bands                   0.640
# Max Normalized Teff WFD night < 730 all bands H...          0.806
# Mean Normalized Teff WFD night < 730 all bands ...          0.640
# Median Normalized Teff WFD night < 730 all band...          0.649
# Min Normalized Teff WFD night < 730 all bands H...          0.429
# N(+3Sigma) Normalized Teff WFD night < 730 all ...          0.000
# N(-3Sigma) Normalized Teff WFD night < 730 all ...          0.000
# Normalized Teff WFD night < 730 all bands Healp...      21495.000
# Rms Normalized Teff WFD night < 730 all bands H...          0.074
#
#                                                     colossus_2653
# Normalized Teff WFD night < 730 all bands                   0.659
# Max Normalized Teff WFD night < 730 all bands H...          1.437
# Mean Normalized Teff WFD night < 730 all bands ...          0.652
# Median Normalized Teff WFD night < 730 all band...          0.668
# Min Normalized Teff WFD night < 730 all bands H...          0.038
# N(+3Sigma) Normalized Teff WFD night < 730 all ...         33.000
# N(-3Sigma) Normalized Teff WFD night < 730 all ...        132.000
# Normalized Teff WFD night < 730 all bands Healp...      22704.000
# Rms Normalized Teff WFD night < 730 all bands H...          0.083

# %% [markdown]
# # Total effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna())
comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna()
# Out:
#                                       baseline2018a  colossus_2653
# Total Teff WFD night < 730 all bands    7539368.502    7015834.816
# Total Teff  night < 730 all bands       8300604.021    7898651.526

# %% [markdown]
# # Open shutter fraction

# %%
df_list.append(comp.summaryStats.T.filter(like='Open',axis=0).dropna())
comp.summaryStats.T.filter(like='Open',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# OpenShutterFraction All visits night <= 730                 0.712
# Max OpenShutterFraction Per night night <= 730 ...          0.760
# Mean OpenShutterFraction Per night night <= 730...          0.711
# Median OpenShutterFraction Per night night <= 7...          0.713
# Min OpenShutterFraction Per night night <= 730 ...          0.601
# N(+3Sigma) OpenShutterFraction Per night night ...          0.000
# N(-3Sigma) OpenShutterFraction Per night night ...          5.000
# OpenShutterFraction Per night night <= 730 OneD...        585.000
# Rms OpenShutterFraction Per night night <= 730 ...          0.024
#
#                                                     colossus_2653
# OpenShutterFraction All visits night <= 730                 0.665
# Max OpenShutterFraction Per night night <= 730 ...          0.743
# Mean OpenShutterFraction Per night night <= 730...          0.668
# Median OpenShutterFraction Per night night <= 7...          0.668
# Min OpenShutterFraction Per night night <= 730 ...          0.551
# N(+3Sigma) OpenShutterFraction Per night night ...          0.000
# N(-3Sigma) OpenShutterFraction Per night night ...          1.000
# OpenShutterFraction Per night night <= 730 OneD...        585.000
# Rms OpenShutterFraction Per night night <= 730 ...          0.035

# %% [markdown]
# # HealpixSkyMaps
#  - Nvisits all bands
#  - Nvisits alt/az all bands
#  - Median airmass all bands
#  - Max airmass all bands
#  - CoaddM5 r band

# %%
n_visits_all, mname = comp.readMetricData(all_dict['NVisits  night < 730 all bands HealpixSlicer']['metricName'],
                                          all_dict['NVisits  night < 730 all bands HealpixSlicer']['metricMetadata'],
                                          all_dict['NVisits  night < 730 all bands HealpixSlicer']['slicerName'])

n_visits_all_alt_az, mname = comp.readMetricData(all_dict['Nvisits as function of Alt/Az night <= 730 all bands HealpixSlicer']['metricName'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 730 all bands HealpixSlicer']['metricMetadata'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 730 all bands HealpixSlicer']['slicerName'])

med_airmass_all, mname = comp.readMetricData(all_dict['Median airmass  night < 730 all bands HealpixSlicer']['metricName'],
                                             all_dict['Median airmass  night < 730 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Median airmass  night < 730 all bands HealpixSlicer']['slicerName'])

max_airmass_all, mname = comp.readMetricData(all_dict['Max airmass  night < 730 all bands HealpixSlicer']['metricName'],
                                             all_dict['Max airmass  night < 730 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Max airmass  night < 730 all bands HealpixSlicer']['slicerName'])

coaddM5_r, mname = comp.readMetricData(all_dict['CoaddM5  night < 730 r band HealpixSlicer']['metricName'],
                                       all_dict['CoaddM5  night < 730 r band HealpixSlicer']['metricMetadata'],
                                       all_dict['CoaddM5  night < 730 r band HealpixSlicer']['slicerName'])

with warnings.catch_warnings():
    comp.plotMetricData(n_visits_all,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'colorMin':0,'colorMax':400, 'xMin':60,'xMax':100},
                        outDir='.',savefig=True)
    comp.plotMetricData(n_visits_all_alt_az,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'xMin':60,'xMax':100,'rot': (90, 90, 90), 'flip': 'geo'},
                        outDir='.',savefig=True)
    comp.plotMetricData(med_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.02,'colorMax':1.31},outDir='.',savefig=True)
    comp.plotMetricData(max_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.1,'colorMax':2.5},outDir='.',savefig=True)
    comp.plotMetricData(coaddM5_r,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':-3.0,'colorMax':0.0},outDir='.',savefig=True)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
coaddM5rBundle = []
for r in runlist:
    coaddM5_r[r].setPlotDict({'color':colors[r],'label':r})
    coaddM5rBundle.append(coaddM5_r[r])
cm5r_ph = plots.PlotHandler()
cm5r_ph.setMetricBundles(coaddM5rBundle)

# %% [markdown]
# # CoaddM5 r band HealpixHistrogram

# %%
# comp.plotMetricData(coaddM5_r,
#                     plotFunc=plots.HealpixHistogram(),
#                     paramTitles=False,
#                     userPlotDict={'figsize':(8,8),'xMin':-0.65,'xMax':0.65,'zp':27.6},outDir='.',savefig=True)
cm5r_ph.plot(plots.HealpixHistogram(),
             plotDicts={'figsize':(8,8),'xMin':-6.0,'xMax':0.,'zp':27.6,'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distributions (OneDSlicer)

# %%
ha_hist_all, mname = comp.readMetricData(all_dict['HA Histogram  night < 730 all bands OneDSlicer']['metricName'],
                                         all_dict['HA Histogram  night < 730 all bands OneDSlicer']['metricMetadata'],
                                         all_dict['HA Histogram  night < 730 all bands OneDSlicer']['slicerName'])

# %%
ha_hist_y, mname = comp.readMetricData(all_dict['HA Histogram  night < 730 y band OneDSlicer']['metricName'],
                                       all_dict['HA Histogram  night < 730 y band OneDSlicer']['metricMetadata'],
                                       all_dict['HA Histogram  night < 730 y band OneDSlicer']['slicerName'])

# %%
HABundle = []
HABundle_y = []
for r in runlist:
    ha_hist_all[r].setPlotDict({'color':colors[r],'label':r})
    ha_hist_y[r].setPlotDict({'color':colors[r],'label':r})
    HABundle.append(ha_hist_all[r])
    HABundle_y.append(ha_hist_y[r])

# %%
ha_ph = plots.PlotHandler()
ha_ph.setMetricBundles(HABundle)

# %%
ha_ph_y = plots.PlotHandler()
ha_ph_y.setMetricBundles(HABundle_y)

# %% [markdown]
# # HA distribution all bands

# %%
fig = ha_ph.plot(plots.OneDBinnedData(),
                 plotDicts={'figsize':(6,6),'xMin':-5.5,'xMax':5.5,'yMax':42000,
                 'bins':np.arange(-10.0,1-.1,0.1),'linewidth':3,
                 'logScale':False})
# plt.figure(fig)
# plt.axvline(x=3)
# plt.axvline(x=-3)
# plt.axvline(x=6)
# plt.axvline(x=-6)
# plt.savefig('log_ha_histogram_halimits.pdf')

# %% [markdown]
# # HA distribution y band

# %%
ha_ph_y.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(8,8),'xMin':-5.0,'xMax':5.0,'yMax':11000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # Slew time and distance distributions

# %%
slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Slew Time Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Time Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Distance Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_hist_bundle_list = []
zoom_slew_hist_bundle_list = []
slew_dist_bundle_list = []
zoom_slew_dist_bundle_list = []

# %%
for r in runlist:
    slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_hist_bundle_list.append(slew_time_hist[r])
    slew_dist_bundle_list.append(slew_dist_hist[r])
    zoom_slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_hist_bundle_list.append(zoom_slew_time_hist[r])
    zoom_slew_dist_bundle_list.append(zoom_slew_dist_hist[r])

# %%
ph_slewhist = plots.PlotHandler()
ph_slewdist = plots.PlotHandler()
zoom_ph_slewhist = plots.PlotHandler()
zoom_ph_slewdist = plots.PlotHandler()

# %%
ph_slewhist.setMetricBundles(slew_hist_bundle_list)
ph_slewdist.setMetricBundles(slew_dist_bundle_list)
zoom_ph_slewhist.setMetricBundles(zoom_slew_hist_bundle_list)
zoom_ph_slewdist.setMetricBundles(zoom_slew_dist_bundle_list)

# %%
ph_slewhist.plot(plots.OneDBinnedData(),
                       plotDicts={'figsize':(6,6),
                                  'xMin':-10,'xMax':150,
                                  'linewidth':2,'bins':np.arange(0,155,5)})
zoom_ph_slewhist.plot(plots.OneDBinnedData(),
                      plotDicts={'figsize':(6,6),
                                 'xMin':-1,'xMax':20,'yMax':72000,
                                 'linewidth':2,'bins':np.arange(0,155,5),'logScale':False})
# Out:
# 2

# %%
ph_slewdist.plot(plots.OneDBinnedData(),
                        plotDicts={'figsize':(6,6),'xMin':-10,
                                   'xMax':140,
                                   'linewidth':2,'bins':np.arange(0,155,1)})
zoom_ph_slewdist.plot(plots.OneDBinnedData(),
                     plotDicts={'figsize':(6,6),'xMin':-1,
                                'xMax':10,'yMax':105000,
                                'linewidth':2,'bins':np.arange(0,155,1),'logScale':False})
# Out:
# 2

# %%
comp.summaryStats.T.to_csv('baseline2018a_vs_colossus_2653_year2.csv')

# %%
cols = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list).T.columns.values

# %%
df_test = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list)

# %%
df_test['idx'] = cols

# %%
new_df = df_test[(df_test['idx'].str.contains('Max|Min|Sigma|Mean|Rms'))==False].round(3)

# %%
new_df[runlist]
# Out:
#                                                     baseline2018a  \
# Fraction of total Nvisits DeepDrillingCosmology...          0.008
# Fraction of total Nvisits WideFastDeep night <=...          0.165
# Fraction of total Nvisits NorthEclipticSpur nig...          0.010
# Fraction of total Nvisits GalacticPlane night <...          0.004
# Fraction of total Nvisits WFD night <= 730                  0.165
# Fraction of total Nvisits All props night <= 730            0.191
# Fraction of total Nvisits SouthCelestialPole ni...          0.004
# Fraction of total Nvisits DD night <= 730                   0.008
# Median NVisits WFD night < 730 u band HealpixSl...         11.000
# Median NVisits WFD night < 730 i band HealpixSl...         31.000
# Median NVisits WFD night < 730 z band HealpixSl...         47.000
# Median NVisits WFD night < 730 y band HealpixSl...         43.000
# Median NVisits WFD night < 730 all bands Healpi...        176.000
# Median NVisits WFD night < 730 r band HealpixSl...         33.000
# Median NVisits WFD night < 730 g band HealpixSl...         14.000
# Median CoaddM5 WFD night < 730 u band HealpixSl...         24.694
# Median CoaddM5 WFD night < 730 i band HealpixSl...         25.600
# Median CoaddM5 WFD night < 730 z band HealpixSl...         25.003
# Median CoaddM5 WFD night < 730 y band HealpixSl...         24.174
# Median CoaddM5 WFD night < 730 r band HealpixSl...         26.231
# Median CoaddM5 WFD night < 730 g band HealpixSl...         26.124
# Median Median seeingEff WFD night < 730 u band ...          0.924
# Median Median seeingEff WFD night < 730 i band ...          0.825
# Median Median seeingEff WFD night < 730 z band ...          0.798
# Median Median seeingEff WFD night < 730 y band ...          0.789
# Median Median seeingEff WFD night < 730 all ban...          0.822
# Median Median seeingEff WFD night < 730 r band ...          0.858
# Median Median seeingEff WFD night < 730 g band ...          0.912
# Median Median airmass WFD night < 730 u band He...          1.043
# Median Median airmass WFD night < 730 i band He...          1.047
# Median Median airmass WFD night < 730 z band He...          1.056
# Median Median airmass WFD night < 730 y band He...          1.053
# Median Median airmass WFD night < 730 all bands...          1.045
# Median Median airmass WFD night < 730 r band He...          1.045
# Median Median airmass WFD night < 730 g band He...          1.046
# Median slewTime All visits                                  5.300
# Filter Changes Whole Survey night <= 730                 1723.000
# Filter Changes Per Night night <= 730 OneDSlicer          585.000
# Median Filter Changes Per Night night <= 730 On...          2.000
# Normalized Teff WFD night < 730 all bands                   0.640
# Median Normalized Teff WFD night < 730 all band...          0.649
# Normalized Teff WFD night < 730 all bands Healp...      21495.000
# Total Teff WFD night < 730 all bands                  7539368.502
# Total Teff  night < 730 all bands                     8300604.021
# OpenShutterFraction All visits night <= 730                 0.712
# Median OpenShutterFraction Per night night <= 7...          0.713
# OpenShutterFraction Per night night <= 730 OneD...        585.000
#
#                                                     colossus_2653
# Fraction of total Nvisits DeepDrillingCosmology...          0.056
# Fraction of total Nvisits WideFastDeep night <=...          0.787
# Fraction of total Nvisits NorthEclipticSpur nig...          0.039
# Fraction of total Nvisits GalacticPlane night <...          0.018
# Fraction of total Nvisits WFD night <= 730                  0.787
# Fraction of total Nvisits All props night <= 730            0.939
# Fraction of total Nvisits SouthCelestialPole ni...          0.040
# Fraction of total Nvisits DD night <= 730                   0.056
# Median NVisits WFD night < 730 u band HealpixSl...         15.000
# Median NVisits WFD night < 730 i band HealpixSl...         37.000
# Median NVisits WFD night < 730 z band HealpixSl...         33.000
# Median NVisits WFD night < 730 y band HealpixSl...         54.000
# Median NVisits WFD night < 730 all bands Healpi...        188.000
# Median NVisits WFD night < 730 r band HealpixSl...         36.000
# Median NVisits WFD night < 730 g band HealpixSl...         12.000
# Median CoaddM5 WFD night < 730 u band HealpixSl...         24.928
# Median CoaddM5 WFD night < 730 i band HealpixSl...         25.672
# Median CoaddM5 WFD night < 730 z band HealpixSl...         24.950
# Median CoaddM5 WFD night < 730 y band HealpixSl...         24.255
# Median CoaddM5 WFD night < 730 r band HealpixSl...         26.154
# Median CoaddM5 WFD night < 730 g band HealpixSl...         25.950
# Median Median seeingEff WFD night < 730 u band ...          0.883
# Median Median seeingEff WFD night < 730 i band ...          0.813
# Median Median seeingEff WFD night < 730 z band ...          0.810
# Median Median seeingEff WFD night < 730 y band ...          0.794
# Median Median seeingEff WFD night < 730 all ban...          0.820
# Median Median seeingEff WFD night < 730 r band ...          0.847
# Median Median seeingEff WFD night < 730 g band ...          0.894
# Median Median airmass WFD night < 730 u band He...          1.054
# Median Median airmass WFD night < 730 i band He...          1.047
# Median Median airmass WFD night < 730 z band He...          1.048
# Median Median airmass WFD night < 730 y band He...          1.056
# Median Median airmass WFD night < 730 all bands...          1.050
# Median Median airmass WFD night < 730 r band He...          1.048
# Median Median airmass WFD night < 730 g band He...          1.049
# Median slewTime All visits                                  5.379
# Filter Changes Whole Survey night <= 730                 2375.000
# Filter Changes Per Night night <= 730 OneDSlicer          585.000
# Median Filter Changes Per Night night <= 730 On...          2.000
# Normalized Teff WFD night < 730 all bands                   0.659
# Median Normalized Teff WFD night < 730 all band...          0.668
# Normalized Teff WFD night < 730 all bands Healp...      22704.000
# Total Teff WFD night < 730 all bands                  7015834.816
# Total Teff  night < 730 all bands                     7898651.526
# OpenShutterFraction All visits night <= 730                 0.665
# Median OpenShutterFraction Per night night <= 7...          0.668
# OpenShutterFraction Per night night <= 730 OneD...        585.000
