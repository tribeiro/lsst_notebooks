# %%
from __future__ import print_function
import lsst.sims.maf.plots as plots
import warnings
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import lsst.sims.maf.metricBundles as mb
import lsst.sims.maf.plots as plots
import lsst.sims.maf.runComparison as rc
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="706863b1-38b4-42ca-bce2-daeb6254cf81">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Setup

# %%
colors = {'baseline2018a_3':'b','colossus_2653_3': 'r'}
runlist = list(colors.keys())

# %%
comp = rc.RunComparison(baseDir='.',runlist=runlist)

# %%
all_dict = comp.buildMetricDict(subdir='all03')

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(all_dict)

# %%
df_list = []

# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format

# %%
nvists = comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Fraction of total Nvisits All props night <= 1095             0.294
# Nvisits All props night <= 1095                          697538.000
# Max Nvisits All props night <= 1095 OneDSlicer             1081.000
# Mean Nvisits All props night <= 1095 OneDSlicer             779.372
# Median Nvisits All props night <= 1095 OneDSlicer           781.000
# Min Nvisits All props night <= 1095 OneDSlicer              181.000
# N(+3Sigma) Nvisits All props night <= 1095 OneD...            0.000
# N(-3Sigma) Nvisits All props night <= 1095 OneD...           10.000
# Nvisits All props night <= 1095 OneDSlicer                  895.000
# Rms Nvisits All props night <= 1095 OneDSlicer              177.980
#
#                                                     colossus_2653_3
# Fraction of total Nvisits All props night <= 1095             0.989
# Nvisits All props night <= 1095                          649431.000
# Max Nvisits All props night <= 1095 OneDSlicer             1008.000
# Mean Nvisits All props night <= 1095 OneDSlicer             725.621
# Median Nvisits All props night <= 1095 OneDSlicer           742.000
# Min Nvisits All props night <= 1095 OneDSlicer              151.000
# N(+3Sigma) Nvisits All props night <= 1095 OneD...            0.000
# N(-3Sigma) Nvisits All props night <= 1095 OneD...           30.000
# Nvisits All props night <= 1095 OneDSlicer                  895.000
# Rms Nvisits All props night <= 1095 OneDSlicer              153.955

# %%
from tabulate import tabulate

# %%
print(tabulate(nvists[runlist], tablefmt="pipe", headers="keys"))
# Out:
# |                                                       |   baseline2018a_3 |   colossus_2653_3 |
# |:------------------------------------------------------|------------------:|------------------:|
# | Fraction of total Nvisits All props night <= 1095     |          0.293985 |          0.989413 |
# | Nvisits All props night <= 1095                       |     697538        |     649431        |
# | Max Nvisits All props night <= 1095 OneDSlicer        |       1081        |       1008        |
# | Mean Nvisits All props night <= 1095 OneDSlicer       |        779.372    |        725.621    |
# | Median Nvisits All props night <= 1095 OneDSlicer     |        781        |        742        |
# | Min Nvisits All props night <= 1095 OneDSlicer        |        181        |        151        |
# | N(+3Sigma) Nvisits All props night <= 1095 OneDSlicer |          0        |          0        |
# | N(-3Sigma) Nvisits All props night <= 1095 OneDSlicer |         10        |         30        |
# | Nvisits All props night <= 1095 OneDSlicer            |        895        |        895        |
# | Rms Nvisits All props night <= 1095 OneDSlicer        |        177.98     |        153.955    |

# %% [markdown]
# # Fraction of Total visits per proposal

# %%
comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Fraction of total Nvisits DeepDrillingCosmology...            0.012
# Fraction of total Nvisits DD night <= 1095                    0.012
# Fraction of total Nvisits GalacticPlane night <...            0.005
# Fraction of total Nvisits All props night <= 1095             0.294
# Fraction of total Nvisits NorthEclipticSpur nig...            0.016
# Fraction of total Nvisits WideFastDeep night <=...            0.255
# Fraction of total Nvisits WFD night <= 1095                   0.255
# Fraction of total Nvisits SouthCelestialPole ni...            0.006
#
#                                                     colossus_2653_3
# Fraction of total Nvisits DeepDrillingCosmology...            0.057
# Fraction of total Nvisits DD night <= 1095                    0.057
# Fraction of total Nvisits GalacticPlane night <...            0.019
# Fraction of total Nvisits All props night <= 1095             0.989
# Fraction of total Nvisits NorthEclipticSpur nig...            0.038
# Fraction of total Nvisits WideFastDeep night <=...            0.838
# Fraction of total Nvisits WFD night <= 1095                   0.838
# Fraction of total Nvisits SouthCelestialPole ni...            0.038

# %% [markdown]
# # Median Nvsits per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Median NVisits WFD night < 1095 all bands Healp...          267.000
# Median NVisits WFD night < 1095 r band HealpixS...           56.000
# Median NVisits WFD night < 1095 i band HealpixS...           51.000
# Median NVisits WFD night < 1095 y band HealpixS...           59.000
# Median NVisits WFD night < 1095 g band HealpixS...           24.000
# Median NVisits WFD night < 1095 u band HealpixS...           18.000
# Median NVisits WFD night < 1095 z band HealpixS...           63.000
#
#                                                     colossus_2653_3
# Median NVisits WFD night < 1095 all bands Healp...          291.000
# Median NVisits WFD night < 1095 r band HealpixS...           56.000
# Median NVisits WFD night < 1095 i band HealpixS...           56.000
# Median NVisits WFD night < 1095 y band HealpixS...           84.000
# Median NVisits WFD night < 1095 g band HealpixS...           19.000
# Median NVisits WFD night < 1095 u band HealpixS...           25.000
# Median NVisits WFD night < 1095 z band HealpixS...           50.000

# %% [markdown]
# # Median CoaddedM5 per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Median CoaddM5 WFD night < 1095 r band HealpixS...           26.556
# Median CoaddM5 WFD night < 1095 i band HealpixS...           25.919
# Median CoaddM5 WFD night < 1095 y band HealpixS...           24.337
# Median CoaddM5 WFD night < 1095 g band HealpixS...           26.438
# Median CoaddM5 WFD night < 1095 u band HealpixS...           24.946
# Median CoaddM5 WFD night < 1095 z band HealpixS...           25.177
#
#                                                     colossus_2653_3
# Median CoaddM5 WFD night < 1095 r band HealpixS...           26.437
# Median CoaddM5 WFD night < 1095 i band HealpixS...           25.915
# Median CoaddM5 WFD night < 1095 y band HealpixS...           24.525
# Median CoaddM5 WFD night < 1095 g band HealpixS...           26.192
# Median CoaddM5 WFD night < 1095 u band HealpixS...           25.206
# Median CoaddM5 WFD night < 1095 z band HealpixS...           25.221

# %% [markdown]
# # Median seeingEff per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Median Median seeingEff WFD night < 1095 all ba...            0.811
# Median Median seeingEff WFD night < 1095 r band...            0.834
# Median Median seeingEff WFD night < 1095 i band...            0.802
# Median Median seeingEff WFD night < 1095 y band...            0.776
# Median Median seeingEff WFD night < 1095 g band...            0.867
# Median Median seeingEff WFD night < 1095 u band...            0.926
# Median Median seeingEff WFD night < 1095 z band...            0.796
#
#                                                     colossus_2653_3
# Median Median seeingEff WFD night < 1095 all ba...            0.806
# Median Median seeingEff WFD night < 1095 r band...            0.824
# Median Median seeingEff WFD night < 1095 i band...            0.802
# Median Median seeingEff WFD night < 1095 y band...            0.774
# Median Median seeingEff WFD night < 1095 g band...            0.890
# Median Median seeingEff WFD night < 1095 u band...            0.896
# Median Median seeingEff WFD night < 1095 z band...            0.788

# %% [markdown]
# # Median airmass

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Median Median airmass WFD night < 1095 all band...            1.046
# Median Median airmass WFD night < 1095 r band H...            1.045
# Median Median airmass WFD night < 1095 i band H...            1.048
# Median Median airmass WFD night < 1095 y band H...            1.059
# Median Median airmass WFD night < 1095 g band H...            1.045
# Median Median airmass WFD night < 1095 u band H...            1.043
# Median Median airmass WFD night < 1095 z band H...            1.056
#
#                                                     colossus_2653_3
# Median Median airmass WFD night < 1095 all band...            1.051
# Median Median airmass WFD night < 1095 r band H...            1.048
# Median Median airmass WFD night < 1095 i band H...            1.047
# Median Median airmass WFD night < 1095 y band H...            1.056
# Median Median airmass WFD night < 1095 g band H...            1.048
# Median Median airmass WFD night < 1095 u band H...            1.056
# Median Median airmass WFD night < 1095 z band H...            1.048

# %% [markdown]
# # Slew statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='slew',axis=0).dropna())
comp.summaryStats.T.filter(like='slew',axis=0).dropna()
# Out:
#                                baseline2018a_3  colossus_2653_3
# Mean slewTime night <= 1095              8.168           11.298
# Median slewTime night <= 1095            5.242            5.396
# Min slewTime night <= 1095               2.000            2.000
# Max slewTime night <= 1095             142.987          140.000

# %%
comp.summaryStats.T.filter(like='Slew',axis=0).dropna()
# Out:
#                           baseline2018a_3  colossus_2653_3
# Slew Count night <= 1095       697538.000       649431.000

# %% [markdown]
# # Filter change statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='Filter',axis=0).dropna())
comp.summaryStats.T.filter(like='Filter',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Filter Changes Whole Survey night <= 1095                  2728.000
# Filter Changes Per Night night <= 1095 OneDSlicer           895.000
# Max Filter Changes Per Night night <= 1095 OneD...           23.000
# Mean Filter Changes Per Night night <= 1095 One...            2.723
# Median Filter Changes Per Night night <= 1095 O...            2.000
# Min Filter Changes Per Night night <= 1095 OneD...            0.000
# N(+3Sigma) Filter Changes Per Night night <= 10...           13.000
# N(-3Sigma) Filter Changes Per Night night <= 10...            0.000
# Rms Filter Changes Per Night night <= 1095 OneD...            3.119
#
#                                                     colossus_2653_3
# Filter Changes Whole Survey night <= 1095                  3684.000
# Filter Changes Per Night night <= 1095 OneDSlicer           895.000
# Max Filter Changes Per Night night <= 1095 OneD...            9.000
# Mean Filter Changes Per Night night <= 1095 One...            3.139
# Median Filter Changes Per Night night <= 1095 O...            2.000
# Min Filter Changes Per Night night <= 1095 OneD...            0.000
# N(+3Sigma) Filter Changes Per Night night <= 10...            0.000
# N(-3Sigma) Filter Changes Per Night night <= 10...            0.000
# Rms Filter Changes Per Night night <= 1095 OneD...            2.566

# %% [markdown]
# # Normalized effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Normalized Teff WFD night < 1095 all bands',axis=0).dropna())
comp.summaryStats.T.filter(like='Normalized Teff WFD night < 1095 all bands',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# Normalized Teff WFD night < 1095 all bands                    0.641
# Max Normalized Teff WFD night < 1095 all bands ...            0.814
# Mean Normalized Teff WFD night < 1095 all bands...            0.641
# Median Normalized Teff WFD night < 1095 all ban...            0.644
# Min Normalized Teff WFD night < 1095 all bands ...            0.428
# N(+3Sigma) Normalized Teff WFD night < 1095 all...            0.000
# N(-3Sigma) Normalized Teff WFD night < 1095 all...            0.000
# Normalized Teff WFD night < 1095 all bands Heal...        21495.000
# Rms Normalized Teff WFD night < 1095 all bands ...            0.079
#
#                                                     colossus_2653_3
# Normalized Teff WFD night < 1095 all bands                    0.685
# Max Normalized Teff WFD night < 1095 all bands ...            1.621
# Mean Normalized Teff WFD night < 1095 all bands...            0.679
# Median Normalized Teff WFD night < 1095 all ban...            0.697
# Min Normalized Teff WFD night < 1095 all bands ...            0.038
# N(+3Sigma) Normalized Teff WFD night < 1095 all...           39.000
# N(-3Sigma) Normalized Teff WFD night < 1095 all...          114.000
# Normalized Teff WFD night < 1095 all bands Heal...        22775.000
# Rms Normalized Teff WFD night < 1095 all bands ...            0.084

# %% [markdown]
# # Total effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna())
comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna()
# Out:
#                                        baseline2018a_3  colossus_2653_3
# Total Teff WFD night < 1095 all bands     11643377.262     11299160.834
# Total Teff  night < 1095 all bands        12822343.467     12667647.561

# %% [markdown]
# # Open shutter fraction

# %%
df_list.append(comp.summaryStats.T.filter(like='Open',axis=0).dropna())
comp.summaryStats.T.filter(like='Open',axis=0).dropna()
# Out:
#                                                     baseline2018a_3  \
# OpenShutterFraction All visits night <= 1095                  0.711
# Max OpenShutterFraction Per night night <= 1095...            0.765
# Mean OpenShutterFraction Per night night <= 109...            0.711
# Median OpenShutterFraction Per night night <= 1...            0.713
# Min OpenShutterFraction Per night night <= 1095...            0.601
# N(+3Sigma) OpenShutterFraction Per night night ...            0.000
# N(-3Sigma) OpenShutterFraction Per night night ...            6.000
# OpenShutterFraction Per night night <= 1095 One...          895.000
# Rms OpenShutterFraction Per night night <= 1095...            0.024
#
#                                                     colossus_2653_3
# OpenShutterFraction All visits night <= 1095                  0.662
# Max OpenShutterFraction Per night night <= 1095...            0.743
# Mean OpenShutterFraction Per night night <= 109...            0.665
# Median OpenShutterFraction Per night night <= 1...            0.666
# Min OpenShutterFraction Per night night <= 1095...            0.551
# N(+3Sigma) OpenShutterFraction Per night night ...            0.000
# N(-3Sigma) OpenShutterFraction Per night night ...            1.000
# OpenShutterFraction Per night night <= 1095 One...          895.000
# Rms OpenShutterFraction Per night night <= 1095...            0.034

# %% [markdown]
# # HealpixSkyMaps
#  - Nvisits all bands
#  - Nvisits alt/az all bands
#  - Median airmass all bands
#  - Max airmass all bands
#  - CoaddM5 r band

# %%
n_visits_all, mname = comp.readMetricData(all_dict['NVisits  night < 1095 all bands HealpixSlicer']['metricName'],
                                          all_dict['NVisits  night < 1095 all bands HealpixSlicer']['metricMetadata'],
                                          all_dict['NVisits  night < 1095 all bands HealpixSlicer']['slicerName'])

n_visits_all_alt_az, mname = comp.readMetricData(all_dict['Nvisits as function of Alt/Az night <= 1095 all bands HealpixSlicer']['metricName'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 1095 all bands HealpixSlicer']['metricMetadata'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 1095 all bands HealpixSlicer']['slicerName'])

med_airmass_all, mname = comp.readMetricData(all_dict['Median airmass  night < 1095 all bands HealpixSlicer']['metricName'],
                                             all_dict['Median airmass  night < 1095 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Median airmass  night < 1095 all bands HealpixSlicer']['slicerName'])

max_airmass_all, mname = comp.readMetricData(all_dict['Max airmass  night < 1095 all bands HealpixSlicer']['metricName'],
                                             all_dict['Max airmass  night < 1095 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Max airmass  night < 1095 all bands HealpixSlicer']['slicerName'])

coaddM5_r, mname = comp.readMetricData(all_dict['CoaddM5  night < 1095 r band HealpixSlicer']['metricName'],
                                       all_dict['CoaddM5  night < 1095 r band HealpixSlicer']['metricMetadata'],
                                       all_dict['CoaddM5  night < 1095 r band HealpixSlicer']['slicerName'])

with warnings.catch_warnings():
    comp.plotMetricData(n_visits_all,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'colorMin':0,'colorMax':450, 'xMin':60,'xMax':100},
                        outDir='.',savefig=True)
    comp.plotMetricData(n_visits_all_alt_az,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'xMin':60,'xMax':100,'rot': (90, 90, 90), 'flip': 'geo'},
                        outDir='.',savefig=True)
    comp.plotMetricData(med_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.02,'colorMax':1.31},outDir='.',savefig=True)
    comp.plotMetricData(max_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.1,'colorMax':2.5},outDir='.',savefig=True)
    comp.plotMetricData(coaddM5_r,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':-3.0,'colorMax':0.0},outDir='.',savefig=True)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
coaddM5rBundle = []
for r in runlist:
    coaddM5_r[r].setPlotDict({'color':colors[r],'label':r})
    coaddM5rBundle.append(coaddM5_r[r])
cm5r_ph = plots.PlotHandler()
cm5r_ph.setMetricBundles(coaddM5rBundle)

# %% [markdown]
# # CoaddM5 r band HealpixHistrogram

# %%
# comp.plotMetricData(coaddM5_r,
#                     plotFunc=plots.HealpixHistogram(),
#                     paramTitles=False,
#                     userPlotDict={'figsize':(8,8),'xMin':-0.65,'xMax':0.65,'zp':27.6},outDir='.',savefig=True)
cm5r_ph.plot(plots.HealpixHistogram(),
             plotDicts={'figsize':(8,8),'xMin':-6.0,'xMax':0.,'zp':27.6,'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distributions (OneDSlicer)

# %%
ha_hist_all, mname = comp.readMetricData(all_dict['HA Histogram  night < 1095 all bands OneDSlicer']['metricName'],
                                         all_dict['HA Histogram  night < 1095 all bands OneDSlicer']['metricMetadata'],
                                         all_dict['HA Histogram  night < 1095 all bands OneDSlicer']['slicerName'])

# %%
ha_hist_y, mname = comp.readMetricData(all_dict['HA Histogram  night < 1095 y band OneDSlicer']['metricName'],
                                       all_dict['HA Histogram  night < 1095 y band OneDSlicer']['metricMetadata'],
                                       all_dict['HA Histogram  night < 1095 y band OneDSlicer']['slicerName'])

# %%
HABundle = []
HABundle_y = []
for r in runlist:
    ha_hist_all[r].setPlotDict({'color':colors[r],'label':'r','bins':np.arange(-10.0,10.1,1)})
    ha_hist_y[r].setPlotDict({'color':colors[r],'label':r})
    HABundle.append(ha_hist_all[r])
    HABundle_y.append(ha_hist_y[r])

# %%
ha_ph = plots.PlotHandler()
ha_ph.setMetricBundles(HABundle)

# %%
ha_ph_y = plots.PlotHandler()
ha_ph_y.setMetricBundles(HABundle_y)

# %% [markdown]
# # HA distribution all bands

# %%
fig = ha_ph.plot(plots.OneDBinnedData(),
                 plotDicts={'figsize':(6,6),'xMin':-5.5,'xMax':5.5,'yMax':52000,
                 'bins':np.arange(-10.0,10.1,1),'linewidth':3,
                 'logScale':False})
# plt.figure(fig)
# plt.axvline(x=3)
# plt.axvline(x=-3)
# plt.axvline(x=6)
# plt.axvline(x=-6)
# plt.savefig('log_ha_histogram_halimits.pdf')

# %% [markdown]
# # HA distribution y band

# %%
ha_ph_y.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(8,8),'xMin':-5.0,'xMax':5.0,'yMax':17000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # Slew time and distance distributions

# %%
slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Slew Time Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Time Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Distance Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_hist_bundle_list = []
zoom_slew_hist_bundle_list = []
slew_dist_bundle_list = []
zoom_slew_dist_bundle_list = []

# %%
for r in runlist:
    slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_hist_bundle_list.append(slew_time_hist[r])
    slew_dist_bundle_list.append(slew_dist_hist[r])
    zoom_slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_hist_bundle_list.append(zoom_slew_time_hist[r])
    zoom_slew_dist_bundle_list.append(zoom_slew_dist_hist[r])

# %%
ph_slewhist = plots.PlotHandler()
ph_slewdist = plots.PlotHandler()
zoom_ph_slewhist = plots.PlotHandler()
zoom_ph_slewdist = plots.PlotHandler()

# %%
ph_slewhist.setMetricBundles(slew_hist_bundle_list)
ph_slewdist.setMetricBundles(slew_dist_bundle_list)
zoom_ph_slewhist.setMetricBundles(zoom_slew_hist_bundle_list)
zoom_ph_slewdist.setMetricBundles(zoom_slew_dist_bundle_list)

# %%
ph_slewhist.plot(plots.OneDBinnedData(),
                       plotDicts={'figsize':(6,6),
                                  'xMin':-10,'xMax':150,
                                  'linewidth':2,'bins':np.arange(0,155,5)})
zoom_ph_slewhist.plot(plots.OneDBinnedData(),
                      plotDicts={'figsize':(6,6),
                                 'xMin':-1,'xMax':20,'yMax':145000,
                                 'linewidth':2,'bins':np.arange(0,155,5),'logScale':False})
# Out:
# 2

# %%
ph_slewdist.plot(plots.OneDBinnedData(),
                        plotDicts={'figsize':(6,6),'xMin':-10,
                                   'xMax':140,
                                   'linewidth':2,'bins':np.arange(0,155,1)})
zoom_ph_slewdist.plot(plots.OneDBinnedData(),
                     plotDicts={'figsize':(6,6),'xMin':-1,
                                'xMax':10,'yMax':215000,
                                'linewidth':2,'bins':np.arange(0,155,1),'logScale':False})
# Out:
# 2

# %%
comp.summaryStats.T.to_csv('baseline2018a_vs_colossus_2653_year3.csv')

# %%
cols = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list).T.columns.values

# %%
df_test = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list)

# %%
df_test['idx'] = cols

# %%
new_df = df_test[(df_test['idx'].str.contains('Max|Min|Sigma|Mean|Rms'))==False].round(3)

# %%
new_df[runlist]
# Out:
#                                                     baseline2018a_3  \
# Fraction of total Nvisits DeepDrillingCosmology...            0.012
# Fraction of total Nvisits DD night <= 1095                    0.012
# Fraction of total Nvisits GalacticPlane night <...            0.005
# Fraction of total Nvisits All props night <= 1095             0.294
# Fraction of total Nvisits NorthEclipticSpur nig...            0.016
# Fraction of total Nvisits WideFastDeep night <=...            0.255
# Fraction of total Nvisits WFD night <= 1095                   0.255
# Fraction of total Nvisits SouthCelestialPole ni...            0.006
# Median NVisits WFD night < 1095 all bands Healp...          267.000
# Median NVisits WFD night < 1095 r band HealpixS...           56.000
# Median NVisits WFD night < 1095 i band HealpixS...           51.000
# Median NVisits WFD night < 1095 y band HealpixS...           59.000
# Median NVisits WFD night < 1095 g band HealpixS...           24.000
# Median NVisits WFD night < 1095 u band HealpixS...           18.000
# Median NVisits WFD night < 1095 z band HealpixS...           63.000
# Median CoaddM5 WFD night < 1095 r band HealpixS...           26.556
# Median CoaddM5 WFD night < 1095 i band HealpixS...           25.919
# Median CoaddM5 WFD night < 1095 y band HealpixS...           24.337
# Median CoaddM5 WFD night < 1095 g band HealpixS...           26.438
# Median CoaddM5 WFD night < 1095 u band HealpixS...           24.946
# Median CoaddM5 WFD night < 1095 z band HealpixS...           25.177
# Median Median seeingEff WFD night < 1095 all ba...            0.811
# Median Median seeingEff WFD night < 1095 r band...            0.834
# Median Median seeingEff WFD night < 1095 i band...            0.802
# Median Median seeingEff WFD night < 1095 y band...            0.776
# Median Median seeingEff WFD night < 1095 g band...            0.867
# Median Median seeingEff WFD night < 1095 u band...            0.926
# Median Median seeingEff WFD night < 1095 z band...            0.796
# Median Median airmass WFD night < 1095 all band...            1.046
# Median Median airmass WFD night < 1095 r band H...            1.045
# Median Median airmass WFD night < 1095 i band H...            1.048
# Median Median airmass WFD night < 1095 y band H...            1.059
# Median Median airmass WFD night < 1095 g band H...            1.045
# Median Median airmass WFD night < 1095 u band H...            1.043
# Median Median airmass WFD night < 1095 z band H...            1.056
# Median slewTime night <= 1095                                 5.242
# Filter Changes Whole Survey night <= 1095                  2728.000
# Filter Changes Per Night night <= 1095 OneDSlicer           895.000
# Median Filter Changes Per Night night <= 1095 O...            2.000
# Total Teff WFD night < 1095 all bands                  11643377.262
# Total Teff  night < 1095 all bands                     12822343.467
# OpenShutterFraction All visits night <= 1095                  0.711
# Median OpenShutterFraction Per night night <= 1...            0.713
# OpenShutterFraction Per night night <= 1095 One...          895.000
#
#                                                     colossus_2653_3
# Fraction of total Nvisits DeepDrillingCosmology...            0.057
# Fraction of total Nvisits DD night <= 1095                    0.057
# Fraction of total Nvisits GalacticPlane night <...            0.019
# Fraction of total Nvisits All props night <= 1095             0.989
# Fraction of total Nvisits NorthEclipticSpur nig...            0.038
# Fraction of total Nvisits WideFastDeep night <=...            0.838
# Fraction of total Nvisits WFD night <= 1095                   0.838
# Fraction of total Nvisits SouthCelestialPole ni...            0.038
# Median NVisits WFD night < 1095 all bands Healp...          291.000
# Median NVisits WFD night < 1095 r band HealpixS...           56.000
# Median NVisits WFD night < 1095 i band HealpixS...           56.000
# Median NVisits WFD night < 1095 y band HealpixS...           84.000
# Median NVisits WFD night < 1095 g band HealpixS...           19.000
# Median NVisits WFD night < 1095 u band HealpixS...           25.000
# Median NVisits WFD night < 1095 z band HealpixS...           50.000
# Median CoaddM5 WFD night < 1095 r band HealpixS...           26.437
# Median CoaddM5 WFD night < 1095 i band HealpixS...           25.915
# Median CoaddM5 WFD night < 1095 y band HealpixS...           24.525
# Median CoaddM5 WFD night < 1095 g band HealpixS...           26.192
# Median CoaddM5 WFD night < 1095 u band HealpixS...           25.206
# Median CoaddM5 WFD night < 1095 z band HealpixS...           25.221
# Median Median seeingEff WFD night < 1095 all ba...            0.806
# Median Median seeingEff WFD night < 1095 r band...            0.824
# Median Median seeingEff WFD night < 1095 i band...            0.802
# Median Median seeingEff WFD night < 1095 y band...            0.774
# Median Median seeingEff WFD night < 1095 g band...            0.890
# Median Median seeingEff WFD night < 1095 u band...            0.896
# Median Median seeingEff WFD night < 1095 z band...            0.788
# Median Median airmass WFD night < 1095 all band...            1.051
# Median Median airmass WFD night < 1095 r band H...            1.048
# Median Median airmass WFD night < 1095 i band H...            1.047
# Median Median airmass WFD night < 1095 y band H...            1.056
# Median Median airmass WFD night < 1095 g band H...            1.048
# Median Median airmass WFD night < 1095 u band H...            1.056
# Median Median airmass WFD night < 1095 z band H...            1.048
# Median slewTime night <= 1095                                 5.396
# Filter Changes Whole Survey night <= 1095                  3684.000
# Filter Changes Per Night night <= 1095 OneDSlicer           895.000
# Median Filter Changes Per Night night <= 1095 O...            2.000
# Total Teff WFD night < 1095 all bands                  11299160.834
# Total Teff  night < 1095 all bands                     12667647.561
# OpenShutterFraction All visits night <= 1095                  0.662
# Median OpenShutterFraction Per night night <= 1...            0.666
# OpenShutterFraction Per night night <= 1095 One...          895.000
