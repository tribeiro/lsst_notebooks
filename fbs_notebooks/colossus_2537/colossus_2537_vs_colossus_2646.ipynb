# %%
from __future__ import print_function
import lsst.sims.maf.plots as plots
import warnings
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import lsst.sims.maf.metricBundles as mb
import lsst.sims.maf.plots as plots
import lsst.sims.maf.runComparison as rc
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f67d4595-9da0-4e80-873c-a477132c6cbe">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Setup

# %%
colors = {'colossus_2537':'b','colossus_2646': 'r'}
runlist = list(colors.keys())

# %%
comp = rc.RunComparison(baseDir='.',runlist=runlist)

# %%
srd_dict = comp.buildMetricDict(subdir='srd')

# %%
all_dict = comp.buildMetricDict(subdir='all')

# %%
cadence_dict = comp.buildMetricDict(subdir='cadence')

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(srd_dict)

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(all_dict)

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(cadence_dict)

# %% [markdown]
# # fO summary statisitics

# %%
comp.summaryStats.T.filter(like='fO',axis=0)
# Out:
#                                                     colossus_2537  \
# fOArea: Nvisits (#) fO All visits HealpixSlicer        653.000000
# fOArea: Nvisits/benchmark fO All visits Healpix...       0.791515
# fONv: Area (sqdeg) fO All visits HealpixSlicer       16606.264064
# fONv: Area/benchmark fO All visits HealpixSlicer         0.922570
# fOArea: Nvisits (#) fO WFD HealpixSlicer              -666.000000
# fOArea: Nvisits/benchmark fO WFD HealpixSlicer        -666.000000
# fONv: Area (sqdeg) fO WFD HealpixSlicer              15897.900228
# fONv: Area/benchmark fO WFD HealpixSlicer                0.883217
#
#                                                     colossus_2646
# fOArea: Nvisits (#) fO All visits HealpixSlicer        709.000000
# fOArea: Nvisits/benchmark fO All visits Healpix...       0.859394
# fONv: Area (sqdeg) fO All visits HealpixSlicer       17738.471192
# fONv: Area/benchmark fO All visits HealpixSlicer         0.985471
# fOArea: Nvisits (#) fO WFD HealpixSlicer               432.000000
# fOArea: Nvisits/benchmark fO WFD HealpixSlicer           0.523636
# fONv: Area (sqdeg) fO WFD HealpixSlicer              17260.913107
# fONv: Area/benchmark fO WFD HealpixSlicer                0.958940

# %% [markdown]
# # Parallax

# %%
comp.summaryStats.T.filter(like='Median Parallax',axis=0).dropna()
# Out:
#                                                     colossus_2537  \
# Median Parallax Error @ 22.4 All visits Healpix...       1.860517
# Median Parallax Error @ 24.0 All visits Healpix...       7.330049
# Median Parallax Coverage @ 22.4 All visits Heal...       0.555689
# Median Parallax Coverage @ 24.0 All visits Heal...       0.545033
# Median Parallax-DCR degeneracy @ 22.4 All visit...       0.281377
# Median Parallax-DCR degeneracy @ 24.0 All visit...       0.279177
# Median Parallax Error @ 22.4 WFD HealpixSlicer           1.614687
# Median Parallax Error @ 24.0 WFD HealpixSlicer           6.259218
# Median Parallax Coverage @ 22.4 WFD HealpixSlicer        0.580952
# Median Parallax Coverage @ 24.0 WFD HealpixSlicer        0.570508
# Median Parallax-DCR degeneracy @ 22.4 WFD Healp...       0.252843
# Median Parallax-DCR degeneracy @ 24.0 WFD Healp...       0.248696
#
#                                                     colossus_2646
# Median Parallax Error @ 22.4 All visits Healpix...       1.879195
# Median Parallax Error @ 24.0 All visits Healpix...       7.410334
# Median Parallax Coverage @ 22.4 All visits Heal...       0.584661
# Median Parallax Coverage @ 24.0 All visits Heal...       0.575772
# Median Parallax-DCR degeneracy @ 22.4 All visit...       0.285838
# Median Parallax-DCR degeneracy @ 24.0 All visit...       0.277398
# Median Parallax Error @ 22.4 WFD HealpixSlicer           1.711611
# Median Parallax Error @ 24.0 WFD HealpixSlicer           6.680559
# Median Parallax Coverage @ 22.4 WFD HealpixSlicer        0.606619
# Median Parallax Coverage @ 24.0 WFD HealpixSlicer        0.598591
# Median Parallax-DCR degeneracy @ 22.4 WFD Healp...       0.309513
# Median Parallax-DCR degeneracy @ 24.0 WFD Healp...       0.298203

# %% [markdown]
# # Proper motion

# %%
comp.summaryStats.T.filter(like='Median Proper Motion',axis=0).dropna()
# Out:
#                                                     colossus_2537  \
# Median Proper Motion Error @ 20.5 All visits He...       0.170077
# Median Proper Motion Error @ 24.0 All visits He...       1.781431
# Median Proper Motion Error @ 20.5 WFD HealpixSl...       0.160789
# Median Proper Motion Error @ 24.0 WFD HealpixSl...       1.619395
#
#                                                     colossus_2646
# Median Proper Motion Error @ 20.5 All visits He...       0.169556
# Median Proper Motion Error @ 24.0 All visits He...       1.840257
# Median Proper Motion Error @ 20.5 WFD HealpixSl...       0.166064
# Median Proper Motion Error @ 24.0 WFD HealpixSl...       1.730705

# %% [markdown]
# # Rapid revisit

# %%
comp.summaryStats.T.filter(like='Area (sq deg) Number of revisits faster',axis=0).dropna()
# Out:
#                                                     colossus_2537  \
# Area (sq deg) Number of revisits faster than 30...      52.521276
# Area (sq deg) Number of revisits faster than 30...       0.000000
#
#                                                     colossus_2646
# Area (sq deg) Number of revisits faster than 30...      69.747328
# Area (sq deg) Number of revisits faster than 30...       0.000000

# %%
df_list = []

# %%
comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna().loc['Nvisits All props']
# Out:
# colossus_2537    2436517.0
# colossus_2646    2181893.0
# Name: Nvisits All props, dtype: float64

# %% [markdown]
# # Fraction in pairs

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Fraction of visits in pairs',axis=0).dropna())

# %% [markdown]
# # Fraction of Total visits per proposal

# %%
comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna()
# Out:
#                                                   colossus_2537  colossus_2646
# Fraction of total Nvisits All props                    1.000000       1.000000
# Fraction of total Nvisits WideFastDeep                 0.731718       0.815402
# Fraction of total Nvisits DD                           0.050586       0.068046
# Fraction of total Nvisits DeepDrillingCosmology1       0.050586       0.068046
# Fraction of total Nvisits WFD                          0.731718       0.815402
# Fraction of total Nvisits NorthEclipticSpur            0.154336       0.068185
# Fraction of total Nvisits GalacticPlane                0.028119       0.019115
# Fraction of total Nvisits SouthCelestialPole           0.035241       0.029253

# %% [markdown]
# # Median Nvsits per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna()
# Out:
#                                             colossus_2537  colossus_2646
# Median NVisits WFD g band HealpixSlicer              89.0           92.0
# Median NVisits WFD z band HealpixSlicer             194.0          186.0
# Median NVisits WFD y band HealpixSlicer             202.0          192.0
# Median NVisits WFD i band HealpixSlicer             215.0          204.0
# Median NVisits WFD r band HealpixSlicer             214.0          204.0
# Median NVisits WFD u band HealpixSlicer              62.0           67.0
# Median NVisits WFD all bands HealpixSlicer          964.0          946.0

# %% [markdown]
# # Median CoaddedM5 per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna()
# Out:
#                                          colossus_2537  colossus_2646
# Median CoaddM5 WFD g band HealpixSlicer      27.188943      27.149279
# Median CoaddM5 WFD z band HealpixSlicer      25.893338      25.808272
# Median CoaddM5 WFD y band HealpixSlicer      24.965438      24.815838
# Median CoaddM5 WFD i band HealpixSlicer      26.599687      26.526201
# Median CoaddM5 WFD r band HealpixSlicer      27.207107      27.129955
# Median CoaddM5 WFD u band HealpixSlicer      25.645147      25.644178

# %% [markdown]
# # Median seeingEff per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna()
# Out:
#                                                     colossus_2537  \
# Median Median seeingEff WFD g band HealpixSlicer         0.888543
# Median Median seeingEff WFD z band HealpixSlicer         0.793822
# Median Median seeingEff WFD y band HealpixSlicer         0.784306
# Median Median seeingEff WFD i band HealpixSlicer         0.824329
# Median Median seeingEff WFD r band HealpixSlicer         0.846682
# Median Median seeingEff WFD u band HealpixSlicer         0.947011
# Median Median seeingEff WFD all bands HealpixSl...       0.824771
#
#                                                     colossus_2646
# Median Median seeingEff WFD g band HealpixSlicer         0.895287
# Median Median seeingEff WFD z band HealpixSlicer         0.829391
# Median Median seeingEff WFD y band HealpixSlicer         0.837281
# Median Median seeingEff WFD i band HealpixSlicer         0.844026
# Median Median seeingEff WFD r band HealpixSlicer         0.863123
# Median Median seeingEff WFD u band HealpixSlicer         0.948973
# Median Median seeingEff WFD all bands HealpixSl...       0.855962

# %% [markdown]
# # Median airmass

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna()
# Out:
#                                                    colossus_2537  \
# Median Median airmass WFD g band HealpixSlicer          1.042920
# Median Median airmass WFD z band HealpixSlicer          1.043044
# Median Median airmass WFD y band HealpixSlicer          1.043357
# Median Median airmass WFD i band HealpixSlicer          1.042975
# Median Median airmass WFD r band HealpixSlicer          1.042758
# Median Median airmass WFD u band HealpixSlicer          1.042530
# Median Median airmass WFD all bands HealpixSlicer       1.043592
#
#                                                    colossus_2646
# Median Median airmass WFD g band HealpixSlicer          1.047848
# Median Median airmass WFD z band HealpixSlicer          1.062288
# Median Median airmass WFD y band HealpixSlicer          1.137863
# Median Median airmass WFD i band HealpixSlicer          1.051352
# Median Median airmass WFD r band HealpixSlicer          1.051621
# Median Median airmass WFD u band HealpixSlicer          1.050438
# Median Median airmass WFD all bands HealpixSlicer       1.053843

# %% [markdown]
# # Slew statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='slew',axis=0).dropna())
comp.summaryStats.T.filter(like='slew',axis=0).dropna()
# Out:
#                             colossus_2537  colossus_2646
# Mean slewTime All visits        15.684212      11.638055
# Median slewTime All visits       7.310834       5.412055
# Min slewTime All visits          2.000000       2.000000
# Max slewTime All visits        142.998790     140.000000

# %% [markdown]
# # Filter change statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='Filter',axis=0).dropna())
comp.summaryStats.T.filter(like='Filter',axis=0).dropna()
# Out:
#                                                 colossus_2537  colossus_2646
# Filter Changes Whole Survey                      34181.000000   21508.000000
# Filter Changes Per Night OneDSlicer               3351.000000    3025.000000
# Max Filter Changes Per Night OneDSlicer             29.000000      26.000000
# Mean Filter Changes Per Night OneDSlicer             9.214563       6.128264
# Median Filter Changes Per Night OneDSlicer           9.000000       5.000000
# Min Filter Changes Per Night OneDSlicer              0.000000       0.000000
# N(+3Sigma) Filter Changes Per Night OneDSlicer      20.000000      80.000000
# N(-3Sigma) Filter Changes Per Night OneDSlicer       0.000000       0.000000
# Rms Filter Changes Per Night OneDSlicer              4.927790       4.873074

# %% [markdown]
# # Normalized effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Normalized Teff all bands',axis=0).dropna())
comp.summaryStats.T.filter(like='Normalized Teff all bands',axis=0).dropna()
# Out:
#                                                     colossus_2537  \
# Normalized Teff all bands                                0.546175
# Max Normalized Teff all bands HealpixSlicer              1.369076
# Mean Normalized Teff all bands HealpixSlicer             0.505835
# Median Normalized Teff all bands HealpixSlicer           0.559984
# Min Normalized Teff all bands HealpixSlicer              0.021421
# N(+3Sigma) Normalized Teff all bands HealpixSlicer       1.000000
# N(-3Sigma) Normalized Teff all bands HealpixSlicer       0.000000
# Normalized Teff all bands HealpixSlicer              32989.000000
# Rms Normalized Teff all bands HealpixSlicer              0.164605
#
#                                                     colossus_2646
# Normalized Teff all bands                                0.531212
# Max Normalized Teff all bands HealpixSlicer              0.959036
# Mean Normalized Teff all bands HealpixSlicer             0.487929
# Median Normalized Teff all bands HealpixSlicer           0.516255
# Min Normalized Teff all bands HealpixSlicer              0.058435
# N(+3Sigma) Normalized Teff all bands HealpixSlicer       1.000000
# N(-3Sigma) Normalized Teff all bands HealpixSlicer      15.000000
# Normalized Teff all bands HealpixSlicer              31939.000000
# Rms Normalized Teff all bands HealpixSlicer              0.133986

# %% [markdown]
# # Total effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Total Teff all bands',axis=0).dropna())
comp.summaryStats.T.filter(like='Total Teff all bands',axis=0).dropna()
# Out:
#                       colossus_2537  colossus_2646
# Total Teff all bands   39922965.545   34771461.386

# %% [markdown]
# # Open shutter fraction

# %%
df_list.append(comp.summaryStats.T.filter(like='Open',axis=0).dropna())
comp.summaryStats.T.filter(like='Open',axis=0).dropna()
# Out:
#                                                     colossus_2537  \
# OpenShutterFraction All visits                           0.603814
# Max OpenShutterFraction Per night OneDSlicer             0.725148
# Mean OpenShutterFraction Per night OneDSlicer            0.606174
# Median OpenShutterFraction Per night OneDSlicer          0.605049
# Min OpenShutterFraction Per night OneDSlicer             0.524703
# N(+3Sigma) OpenShutterFraction Per night OneDSl...       3.000000
# N(-3Sigma) OpenShutterFraction Per night OneDSl...       0.000000
# OpenShutterFraction Per night OneDSlicer              3351.000000
# Rms OpenShutterFraction Per night OneDSlicer             0.029081
#
#                                                     colossus_2646
# OpenShutterFraction All visits                           0.657346
# Max OpenShutterFraction Per night OneDSlicer             0.734834
# Mean OpenShutterFraction Per night OneDSlicer            0.657944
# Median OpenShutterFraction Per night OneDSlicer          0.658031
# Min OpenShutterFraction Per night OneDSlicer             0.583334
# N(+3Sigma) OpenShutterFraction Per night OneDSl...       0.000000
# N(-3Sigma) OpenShutterFraction Per night OneDSl...       0.000000
# OpenShutterFraction Per night OneDSlicer              3025.000000
# Rms OpenShutterFraction Per night OneDSlicer             0.025913

# %% [markdown]
# # HealpixSkyMaps
#  - Nvisits all bands
#  - Nvisits alt/az all bands
#  - Median airmass all bands
#  - Max airmass all bands
#  - CoaddM5 r band

# %%
n_visits_all, mname = comp.readMetricData(all_dict['NVisits all bands HealpixSlicer']['metricName'],
                                          all_dict['NVisits all bands HealpixSlicer']['metricMetadata'],
                                          all_dict['NVisits all bands HealpixSlicer']['slicerName'])

n_visits_all_alt_az, mname = comp.readMetricData(all_dict['Nvisits as function of Alt/Az all bands HealpixSlicer']['metricName'],
                                                 all_dict['Nvisits as function of Alt/Az all bands HealpixSlicer']['metricMetadata'],
                                                 all_dict['Nvisits as function of Alt/Az all bands HealpixSlicer']['slicerName'])

med_airmass_all, mname = comp.readMetricData(all_dict['Median airmass all bands HealpixSlicer']['metricName'],
                                             all_dict['Median airmass all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Median airmass all bands HealpixSlicer']['slicerName'])

max_airmass_all, mname = comp.readMetricData(all_dict['Max airmass all bands HealpixSlicer']['metricName'],
                                             all_dict['Max airmass all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Max airmass all bands HealpixSlicer']['slicerName'])

coaddM5_r, mname = comp.readMetricData(all_dict['CoaddM5 r band HealpixSlicer']['metricName'],
                                       all_dict['CoaddM5 r band HealpixSlicer']['metricMetadata'],
                                       all_dict['CoaddM5 r band HealpixSlicer']['slicerName'])

para_20, mname = comp.readMetricData(srd_dict['Normalized Parallax @ 22.4 All visits HealpixSlicer']['metricName'],
                                       srd_dict['Normalized Parallax @ 22.4 All visits HealpixSlicer']['metricMetadata'],
                                       srd_dict['Normalized Parallax @ 22.4 All visits HealpixSlicer']['slicerName'])

propmo_20, mname = comp.readMetricData(srd_dict['Normalized Proper Motion @ 20.5 All visits HealpixSlicer']['metricName'],
                                       srd_dict['Normalized Proper Motion @ 20.5 All visits HealpixSlicer']['metricMetadata'],
                                       srd_dict['Normalized Proper Motion @ 20.5 All visits HealpixSlicer']['slicerName'])

with warnings.catch_warnings():
    comp.plotMetricData(n_visits_all,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'colorMin':700,'colorMax':1200, 'xMin':60,'xMax':100},
                        outDir='.',savefig=True)
    comp.plotMetricData(n_visits_all_alt_az,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'xMin':60,'xMax':100,'rot': (90, 90, 90), 'flip': 'geo'},
                        outDir='.',savefig=True)
    comp.plotMetricData(med_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.02,'colorMax':1.31},outDir='.',savefig=True)
    comp.plotMetricData(max_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.1,'colorMax':2.5},outDir='.',savefig=True)
    comp.plotMetricData(coaddM5_r,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':-0.62,'colorMax':0.62,'zp':27.6},outDir='.',savefig=True)
    comp.plotMetricData(para_20,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':0.5,'colorMax':1.0},outDir='.',savefig=True)
    comp.plotMetricData(propmo_20,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':0.42,'colorMax':0.62},outDir='.',savefig=True)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
coaddM5rBundle = []
for r in runlist:
    coaddM5_r[r].setPlotDict({'color':colors[r],'label':r})
    coaddM5rBundle.append(coaddM5_r[r])
cm5r_ph = plots.PlotHandler()
cm5r_ph.setMetricBundles(coaddM5rBundle)

# %% [markdown]
# # CoaddM5 r band HealpixHistrogram

# %%
# comp.plotMetricData(coaddM5_r,
#                     plotFunc=plots.HealpixHistogram(),
#                     paramTitles=False,
#                     userPlotDict={'figsize':(8,8),'xMin':-0.65,'xMax':0.65,'zp':27.6},outDir='.',savefig=True)
cm5r_ph.plot(plots.HealpixHistogram(),
             plotDicts={'figsize':(8,8),'xMin':-1.5,'xMax':0.65,'zp':27.6,'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distributions (OneDSlicer)

# %%
ha_hist_all, mname = comp.readMetricData(all_dict['HA Histogram all bands OneDSlicer']['metricName'],
                                         all_dict['HA Histogram all bands OneDSlicer']['metricMetadata'],
                                         all_dict['HA Histogram all bands OneDSlicer']['slicerName'])

# %%
ha_hist_y, mname = comp.readMetricData(all_dict['HA Histogram y band OneDSlicer']['metricName'],
                                       all_dict['HA Histogram y band OneDSlicer']['metricMetadata'],
                                       all_dict['HA Histogram y band OneDSlicer']['slicerName'])

# %%
HABundle = []
HABundle_y = []
for r in runlist:
    ha_hist_all[r].setPlotDict({'color':colors[r],'label':r})
    ha_hist_y[r].setPlotDict({'color':colors[r],'label':r})
    HABundle.append(ha_hist_all[r])
    HABundle_y.append(ha_hist_y[r])

# %%
ha_ph = plots.PlotHandler()
ha_ph.setMetricBundles(HABundle)

# %%
ha_ph_y = plots.PlotHandler()
ha_ph_y.setMetricBundles(HABundle_y)

# %% [markdown]
# # HA distribution all bands

# %%
ha_ph.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(8,8),'xMin':-5.0,'xMax':5.0,'yMax':220000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distribution y band

# %%
ha_ph_y.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(8,8),'xMin':-5.0,'xMax':5.0,'yMax':45000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # Slew time and distance distributions

# %%
slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Slew Time Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Time Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Distance Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_hist_bundle_list = []
slew_dist_bundle_list = []

# %%
for r in runlist:
    slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_hist_bundle_list.append(slew_time_hist[r])
    slew_dist_bundle_list.append(slew_dist_hist[r])

# %%
ph_slewhist = plots.PlotHandler()
ph_slewdist = plots.PlotHandler()

# %%
ph_slewhist.setMetricBundles(slew_hist_bundle_list)
ph_slewdist.setMetricBundles(slew_dist_bundle_list)

# %%
fig = ph_slewhist.plot(plots.OneDBinnedData(),
                       plotDicts={'figsize':(6,6),
                                  'xMin':-10,'xMax':150,
                                  'linewidth':2,'bins':np.arange(0,155,5)})
# plt.figure(fig)
# plt.savefig('slewTime_hist_combo.pdf',dpi=600,bbox_inches='tight')

# %%
fig2 = ph_slewdist.plot(plots.OneDBinnedData(),
                        plotDicts={'figsize':(6,6),'xMin':-10,
                                   'xMax':140,
                                   'linewidth':2,'bins':np.arange(0,155,1)})

# %%
comp.summaryStats.T.to_csv('colossus_2537_vs_colossus_2646.csv')

# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format

# %%
srd_df = comp.summaryStats.T.filter(like='fO',axis=0).append([comp.summaryStats.T.filter(like='Median Parallax',axis=0).dropna(),
                                                     comp.summaryStats.T.filter(like='Area (sq deg) Number of revisits faster',axis=0).dropna()]).round(3)

# %%
cols_srd = srd_df.T.columns.values

# %%
srd_df['idx'] = cols_srd

# %%
new_srd = srd_df[(srd_df['idx'].str.contains('DCR|Coverage'))==False].round(3)

# %%
cols = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list).T.columns.values

# %%
df_test = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list)

# %%
df_test['idx'] = cols

# %%
new_df = df_test[(df_test['idx'].str.contains('Max|Min|Sigma|Mean|Rms'))==False].round(3)

# %%
new_df[runlist]
# Out:
#                                                     colossus_2537  \
# Fraction of total Nvisits All props                         1.000
# Fraction of total Nvisits WideFastDeep                      0.732
# Fraction of total Nvisits DD                                0.051
# Fraction of total Nvisits DeepDrillingCosmology1            0.051
# Fraction of total Nvisits WFD                               0.732
# Fraction of total Nvisits NorthEclipticSpur                 0.154
# Fraction of total Nvisits GalacticPlane                     0.028
# Fraction of total Nvisits SouthCelestialPole                0.035
# Median Fraction of visits in pairs (15-60 min) ...          0.872
# Median Fraction of visits in pairs (15-60 min) ...          0.874
# Median NVisits WFD g band HealpixSlicer                    89.000
# Median NVisits WFD z band HealpixSlicer                   194.000
# Median NVisits WFD y band HealpixSlicer                   202.000
# Median NVisits WFD i band HealpixSlicer                   215.000
# Median NVisits WFD r band HealpixSlicer                   214.000
# Median NVisits WFD u band HealpixSlicer                    62.000
# Median NVisits WFD all bands HealpixSlicer                964.000
# Median CoaddM5 WFD g band HealpixSlicer                    27.189
# Median CoaddM5 WFD z band HealpixSlicer                    25.893
# Median CoaddM5 WFD y band HealpixSlicer                    24.965
# Median CoaddM5 WFD i band HealpixSlicer                    26.600
# Median CoaddM5 WFD r band HealpixSlicer                    27.207
# Median CoaddM5 WFD u band HealpixSlicer                    25.645
# Median Median seeingEff WFD g band HealpixSlicer            0.889
# Median Median seeingEff WFD z band HealpixSlicer            0.794
# Median Median seeingEff WFD y band HealpixSlicer            0.784
# Median Median seeingEff WFD i band HealpixSlicer            0.824
# Median Median seeingEff WFD r band HealpixSlicer            0.847
# Median Median seeingEff WFD u band HealpixSlicer            0.947
# Median Median seeingEff WFD all bands HealpixSl...          0.825
# Median Median airmass WFD g band HealpixSlicer              1.043
# Median Median airmass WFD z band HealpixSlicer              1.043
# Median Median airmass WFD y band HealpixSlicer              1.043
# Median Median airmass WFD i band HealpixSlicer              1.043
# Median Median airmass WFD r band HealpixSlicer              1.043
# Median Median airmass WFD u band HealpixSlicer              1.043
# Median Median airmass WFD all bands HealpixSlicer           1.044
# Median slewTime All visits                                  7.311
# Filter Changes Whole Survey                             34181.000
# Filter Changes Per Night OneDSlicer                      3351.000
# Median Filter Changes Per Night OneDSlicer                  9.000
# Normalized Teff all bands                                   0.546
# Median Normalized Teff all bands HealpixSlicer              0.560
# Normalized Teff all bands HealpixSlicer                 32989.000
# OpenShutterFraction All visits                              0.604
# Median OpenShutterFraction Per night OneDSlicer             0.605
# OpenShutterFraction Per night OneDSlicer                 3351.000
# OpenShutterFraction All visits                              0.604
# Median OpenShutterFraction Per night OneDSlicer             0.605
# OpenShutterFraction Per night OneDSlicer                 3351.000
# Total Teff all bands                                 39922965.545
#
#                                                     colossus_2646
# Fraction of total Nvisits All props                         1.000
# Fraction of total Nvisits WideFastDeep                      0.815
# Fraction of total Nvisits DD                                0.068
# Fraction of total Nvisits DeepDrillingCosmology1            0.068
# Fraction of total Nvisits WFD                               0.815
# Fraction of total Nvisits NorthEclipticSpur                 0.068
# Fraction of total Nvisits GalacticPlane                     0.019
# Fraction of total Nvisits SouthCelestialPole                0.029
# Median Fraction of visits in pairs (15-60 min) ...          0.760
# Median Fraction of visits in pairs (15-60 min) ...          0.717
# Median NVisits WFD g band HealpixSlicer                    92.000
# Median NVisits WFD z band HealpixSlicer                   186.000
# Median NVisits WFD y band HealpixSlicer                   192.000
# Median NVisits WFD i band HealpixSlicer                   204.000
# Median NVisits WFD r band HealpixSlicer                   204.000
# Median NVisits WFD u band HealpixSlicer                    67.000
# Median NVisits WFD all bands HealpixSlicer                946.000
# Median CoaddM5 WFD g band HealpixSlicer                    27.149
# Median CoaddM5 WFD z band HealpixSlicer                    25.808
# Median CoaddM5 WFD y band HealpixSlicer                    24.816
# Median CoaddM5 WFD i band HealpixSlicer                    26.526
# Median CoaddM5 WFD r band HealpixSlicer                    27.130
# Median CoaddM5 WFD u band HealpixSlicer                    25.644
# Median Median seeingEff WFD g band HealpixSlicer            0.895
# Median Median seeingEff WFD z band HealpixSlicer            0.829
# Median Median seeingEff WFD y band HealpixSlicer            0.837
# Median Median seeingEff WFD i band HealpixSlicer            0.844
# Median Median seeingEff WFD r band HealpixSlicer            0.863
# Median Median seeingEff WFD u band HealpixSlicer            0.949
# Median Median seeingEff WFD all bands HealpixSl...          0.856
# Median Median airmass WFD g band HealpixSlicer              1.048
# Median Median airmass WFD z band HealpixSlicer              1.062
# Median Median airmass WFD y band HealpixSlicer              1.138
# Median Median airmass WFD i band HealpixSlicer              1.051
# Median Median airmass WFD r band HealpixSlicer              1.052
# Median Median airmass WFD u band HealpixSlicer              1.050
# Median Median airmass WFD all bands HealpixSlicer           1.054
# Median slewTime All visits                                  5.412
# Filter Changes Whole Survey                             21508.000
# Filter Changes Per Night OneDSlicer                      3025.000
# Median Filter Changes Per Night OneDSlicer                  5.000
# Normalized Teff all bands                                   0.531
# Median Normalized Teff all bands HealpixSlicer              0.516
# Normalized Teff all bands HealpixSlicer                 31939.000
# OpenShutterFraction All visits                              0.657
# Median OpenShutterFraction Per night OneDSlicer             0.658
# OpenShutterFraction Per night OneDSlicer                 3025.000
# OpenShutterFraction All visits                              0.657
# Median OpenShutterFraction Per night OneDSlicer             0.658
# OpenShutterFraction Per night OneDSlicer                 3025.000
# Total Teff all bands                                 34771461.386

# %%
new_srd[runlist]
# Out:
#                                                     colossus_2537  \
# fOArea: Nvisits (#) fO All visits HealpixSlicer           653.000
# fOArea: Nvisits/benchmark fO All visits Healpix...          0.792
# fONv: Area (sqdeg) fO All visits HealpixSlicer          16606.264
# fONv: Area/benchmark fO All visits HealpixSlicer            0.923
# fOArea: Nvisits (#) fO WFD HealpixSlicer                 -666.000
# fOArea: Nvisits/benchmark fO WFD HealpixSlicer           -666.000
# fONv: Area (sqdeg) fO WFD HealpixSlicer                 15897.900
# fONv: Area/benchmark fO WFD HealpixSlicer                   0.883
# Median Parallax Error @ 22.4 All visits Healpix...          1.861
# Median Parallax Error @ 24.0 All visits Healpix...          7.330
# Median Parallax Error @ 22.4 WFD HealpixSlicer              1.615
# Median Parallax Error @ 24.0 WFD HealpixSlicer              6.259
# Area (sq deg) Number of revisits faster than 30...         52.521
# Area (sq deg) Number of revisits faster than 30...          0.000
#
#                                                     colossus_2646
# fOArea: Nvisits (#) fO All visits HealpixSlicer           709.000
# fOArea: Nvisits/benchmark fO All visits Healpix...          0.859
# fONv: Area (sqdeg) fO All visits HealpixSlicer          17738.471
# fONv: Area/benchmark fO All visits HealpixSlicer            0.985
# fOArea: Nvisits (#) fO WFD HealpixSlicer                  432.000
# fOArea: Nvisits/benchmark fO WFD HealpixSlicer              0.524
# fONv: Area (sqdeg) fO WFD HealpixSlicer                 17260.913
# fONv: Area/benchmark fO WFD HealpixSlicer                   0.959
# Median Parallax Error @ 22.4 All visits Healpix...          1.879
# Median Parallax Error @ 24.0 All visits Healpix...          7.410
# Median Parallax Error @ 22.4 WFD HealpixSlicer              1.712
# Median Parallax Error @ 24.0 WFD HealpixSlicer              6.681
# Area (sq deg) Number of revisits faster than 30...         69.747
# Area (sq deg) Number of revisits faster than 30...          0.000
