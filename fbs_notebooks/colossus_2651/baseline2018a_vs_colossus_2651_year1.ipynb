# %%
from __future__ import print_function
import lsst.sims.maf.plots as plots
import warnings
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import lsst.sims.maf.metricBundles as mb
import lsst.sims.maf.plots as plots
import lsst.sims.maf.runComparison as rc
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="26d7e8ec-e83b-46b7-af15-0617971e903e">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Setup

# %%
colors = {'baseline2018a':'b','colossus_2651': 'r'}
runlist = list(colors.keys())

# %%
comp = rc.RunComparison(baseDir='.',runlist=runlist)

# %%
all_dict = comp.buildMetricDict(subdir='all01')

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(all_dict)

# %%
df_list = []

# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format

# %%
comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Fraction of total Nvisits All props night <= 365            0.096
# Nvisits All props night <= 365                         228336.000
# Max Nvisits All props night <= 365 OneDSlicer            1081.000
# Mean Nvisits All props night <= 365 OneDSlicer            790.090
# Median Nvisits All props night <= 365 OneDSlicer          786.000
# Min Nvisits All props night <= 365 OneDSlicer             181.000
# N(+3Sigma) Nvisits All props night <= 365 OneDS...          0.000
# N(-3Sigma) Nvisits All props night <= 365 OneDS...          7.000
# Nvisits All props night <= 365 OneDSlicer                 289.000
# Rms Nvisits All props night <= 365 OneDSlicer             158.714
#
#                                                     colossus_2651
# Fraction of total Nvisits All props night <= 365            1.000
# Nvisits All props night <= 365                         222785.000
# Max Nvisits All props night <= 365 OneDSlicer            1013.000
# Mean Nvisits All props night <= 365 OneDSlicer            770.882
# Median Nvisits All props night <= 365 OneDSlicer          790.000
# Min Nvisits All props night <= 365 OneDSlicer             178.000
# N(+3Sigma) Nvisits All props night <= 365 OneDS...          0.000
# N(-3Sigma) Nvisits All props night <= 365 OneDS...          7.000
# Nvisits All props night <= 365 OneDSlicer                 289.000
# Rms Nvisits All props night <= 365 OneDSlicer             143.816

# %% [markdown]
# # Fraction of Total visits per proposal

# %%
comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Fraction of total Nvisits SouthCelestialPole ni...          0.002
# Fraction of total Nvisits WFD night <= 365                  0.083
# Fraction of total Nvisits GalacticPlane night <...          0.002
# Fraction of total Nvisits DD night <= 365                   0.004
# Fraction of total Nvisits NorthEclipticSpur nig...          0.005
# Fraction of total Nvisits DeepDrillingCosmology...          0.004
# Fraction of total Nvisits All props night <= 365            0.096
# Fraction of total Nvisits WideFastDeep night <=...          0.083
#
#                                                     colossus_2651
# Fraction of total Nvisits SouthCelestialPole ni...          0.038
# Fraction of total Nvisits WFD night <= 365                  0.826
# Fraction of total Nvisits GalacticPlane night <...          0.018
# Fraction of total Nvisits DD night <= 365                   0.067
# Fraction of total Nvisits NorthEclipticSpur nig...          0.050
# Fraction of total Nvisits DeepDrillingCosmology...          0.067
# Fraction of total Nvisits All props night <= 365            1.000
# Fraction of total Nvisits WideFastDeep night <=...          0.826

# %% [markdown]
# # Median Nvsits per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median NVisits WFD night < 365 all bands Healpi...         90.000
# Median NVisits WFD night < 365 g band HealpixSl...          6.000
# Median NVisits WFD night < 365 y band HealpixSl...         24.000
# Median NVisits WFD night < 365 z band HealpixSl...         28.000
# Median NVisits WFD night < 365 i band HealpixSl...         12.000
# Median NVisits WFD night < 365 r band HealpixSl...         16.000
# Median NVisits WFD night < 365 u band HealpixSl...          6.000
#
#                                                     colossus_2651
# Median NVisits WFD night < 365 all bands Healpi...         97.000
# Median NVisits WFD night < 365 g band HealpixSl...          6.000
# Median NVisits WFD night < 365 y band HealpixSl...         26.000
# Median NVisits WFD night < 365 z band HealpixSl...         19.000
# Median NVisits WFD night < 365 i band HealpixSl...         20.000
# Median NVisits WFD night < 365 r band HealpixSl...         19.000
# Median NVisits WFD night < 365 u band HealpixSl...          7.000

# %% [markdown]
# # Median CoaddedM5 per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median CoaddM5 WFD night < 365 g band HealpixSl...         25.757
# Median CoaddM5 WFD night < 365 y band HealpixSl...         23.908
# Median CoaddM5 WFD night < 365 z band HealpixSl...         24.766
# Median CoaddM5 WFD night < 365 i band HealpixSl...         25.191
# Median CoaddM5 WFD night < 365 r band HealpixSl...         25.890
# Median CoaddM5 WFD night < 365 u band HealpixSl...         24.436
#
#                                                     colossus_2651
# Median CoaddM5 WFD night < 365 g band HealpixSl...         25.640
# Median CoaddM5 WFD night < 365 y band HealpixSl...         23.875
# Median CoaddM5 WFD night < 365 z band HealpixSl...         24.652
# Median CoaddM5 WFD night < 365 i band HealpixSl...         25.358
# Median CoaddM5 WFD night < 365 r band HealpixSl...         25.918
# Median CoaddM5 WFD night < 365 u band HealpixSl...         24.575

# %% [markdown]
# # Median seeingEff per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median Median seeingEff WFD night < 365 all ban...          0.780
# Median Median seeingEff WFD night < 365 g band ...          0.858
# Median Median seeingEff WFD night < 365 y band ...          0.753
# Median Median seeingEff WFD night < 365 z band ...          0.774
# Median Median seeingEff WFD night < 365 i band ...          0.764
# Median Median seeingEff WFD night < 365 r band ...          0.810
# Median Median seeingEff WFD night < 365 u band ...          0.844
#
#                                                     colossus_2651
# Median Median seeingEff WFD night < 365 all ban...          0.784
# Median Median seeingEff WFD night < 365 g band ...          0.803
# Median Median seeingEff WFD night < 365 y band ...          0.766
# Median Median seeingEff WFD night < 365 z band ...          0.777
# Median Median seeingEff WFD night < 365 i band ...          0.794
# Median Median seeingEff WFD night < 365 r band ...          0.797
# Median Median seeingEff WFD night < 365 u band ...          0.817

# %% [markdown]
# # Median airmass

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Median Median airmass WFD night < 365 all bands...          1.044
# Median Median airmass WFD night < 365 g band He...          1.046
# Median Median airmass WFD night < 365 y band He...          1.047
# Median Median airmass WFD night < 365 z band He...          1.057
# Median Median airmass WFD night < 365 i band He...          1.047
# Median Median airmass WFD night < 365 r band He...          1.044
# Median Median airmass WFD night < 365 u band He...          1.042
#
#                                                     colossus_2651
# Median Median airmass WFD night < 365 all bands...          1.061
# Median Median airmass WFD night < 365 g band He...          1.056
# Median Median airmass WFD night < 365 y band He...          1.087
# Median Median airmass WFD night < 365 z band He...          1.062
# Median Median airmass WFD night < 365 i band He...          1.056
# Median Median airmass WFD night < 365 r band He...          1.056
# Median Median airmass WFD night < 365 u band He...          1.074

# %% [markdown]
# # Slew statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='slew',axis=0).dropna())
comp.summaryStats.T.filter(like='slew',axis=0).dropna()
# Out:
#                             baseline2018a  colossus_2651
# Mean slewTime All visits            8.139          9.229
# Median slewTime All visits          5.300          5.119
# Min slewTime All visits             2.000          2.000
# Max slewTime All visits           142.959        140.000

# %% [markdown]
# # Filter change statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='Filter',axis=0).dropna())
comp.summaryStats.T.filter(like='Filter',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Filter Changes Whole Survey night <= 365                  758.000
# Filter Changes Per Night night <= 365 OneDSlicer          289.000
# Max Filter Changes Per Night night <= 365 OneDS...         21.000
# Mean Filter Changes Per Night night <= 365 OneD...          2.370
# Median Filter Changes Per Night night <= 365 On...          2.000
# Min Filter Changes Per Night night <= 365 OneDS...          0.000
# N(+3Sigma) Filter Changes Per Night night <= 36...          4.000
# N(-3Sigma) Filter Changes Per Night night <= 36...          0.000
# Rms Filter Changes Per Night night <= 365 OneDS...          3.154
#
#                                                     colossus_2651
# Filter Changes Whole Survey night <= 365                 1283.000
# Filter Changes Per Night night <= 365 OneDSlicer          289.000
# Max Filter Changes Per Night night <= 365 OneDS...         22.000
# Mean Filter Changes Per Night night <= 365 OneD...          4.059
# Median Filter Changes Per Night night <= 365 On...          2.000
# Min Filter Changes Per Night night <= 365 OneDS...          0.000
# N(+3Sigma) Filter Changes Per Night night <= 36...         11.000
# N(-3Sigma) Filter Changes Per Night night <= 36...          0.000
# Rms Filter Changes Per Night night <= 365 OneDS...          5.060

# %% [markdown]
# # Normalized effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Normalized Teff WFD night < 365 all bands',axis=0).dropna())
comp.summaryStats.T.filter(like='Normalized Teff WFD night < 365 all bands',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# Normalized Teff WFD night < 365 all bands                   0.734
# Max Normalized Teff WFD night < 365 all bands H...          0.971
# Mean Normalized Teff WFD night < 365 all bands ...          0.731
# Median Normalized Teff WFD night < 365 all band...          0.731
# Min Normalized Teff WFD night < 365 all bands H...          0.455
# N(+3Sigma) Normalized Teff WFD night < 365 all ...          0.000
# N(-3Sigma) Normalized Teff WFD night < 365 all ...          0.000
# Normalized Teff WFD night < 365 all bands Healp...      21495.000
# Rms Normalized Teff WFD night < 365 all bands H...          0.096
#
#                                                     colossus_2651
# Normalized Teff WFD night < 365 all bands                   0.699
# Max Normalized Teff WFD night < 365 all bands H...          1.769
# Mean Normalized Teff WFD night < 365 all bands ...          0.695
# Median Normalized Teff WFD night < 365 all band...          0.701
# Min Normalized Teff WFD night < 365 all bands H...          0.055
# N(+3Sigma) Normalized Teff WFD night < 365 all ...         51.000
# N(-3Sigma) Normalized Teff WFD night < 365 all ...        104.000
# Normalized Teff WFD night < 365 all bands Healp...      22618.000
# Rms Normalized Teff WFD night < 365 all bands H...          0.092

# %% [markdown]
# # Total effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna())
comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna()
# Out:
#                                       baseline2018a  colossus_2651
# Total Teff WFD night < 365 all bands    4347843.312    3857360.215
# Total Teff  night < 365 all bands       4784024.013    4409311.994

# %% [markdown]
# # Open shutter fraction

# %%
df_list.append(comp.summaryStats.T.filter(like='Open',axis=0).dropna())
comp.summaryStats.T.filter(like='Open',axis=0).dropna()
# Out:
#                                                     baseline2018a  \
# OpenShutterFraction All visits night <= 365                 0.712
# Max OpenShutterFraction Per night night <= 365 ...          0.760
# Mean OpenShutterFraction Per night night <= 365...          0.712
# Median OpenShutterFraction Per night night <= 3...          0.714
# Min OpenShutterFraction Per night night <= 365 ...          0.601
# N(+3Sigma) OpenShutterFraction Per night night ...          0.000
# N(-3Sigma) OpenShutterFraction Per night night ...          1.000
# OpenShutterFraction Per night night <= 365 OneD...        289.000
# Rms OpenShutterFraction Per night night <= 365 ...          0.022
#
#                                                     colossus_2651
# OpenShutterFraction All visits night <= 365                 0.694
# Max OpenShutterFraction Per night night <= 365 ...          0.762
# Mean OpenShutterFraction Per night night <= 365...          0.696
# Median OpenShutterFraction Per night night <= 3...          0.696
# Min OpenShutterFraction Per night night <= 365 ...          0.615
# N(+3Sigma) OpenShutterFraction Per night night ...          0.000
# N(-3Sigma) OpenShutterFraction Per night night ...          0.000
# OpenShutterFraction Per night night <= 365 OneD...        289.000
# Rms OpenShutterFraction Per night night <= 365 ...          0.029

# %% [markdown]
# # HealpixSkyMaps
#  - Nvisits all bands
#  - Nvisits alt/az all bands
#  - Median airmass all bands
#  - Max airmass all bands
#  - CoaddM5 r band

# %%
n_visits_all, mname = comp.readMetricData(all_dict['NVisits  night < 365 all bands HealpixSlicer']['metricName'],
                                          all_dict['NVisits  night < 365 all bands HealpixSlicer']['metricMetadata'],
                                          all_dict['NVisits  night < 365 all bands HealpixSlicer']['slicerName'])

n_visits_all_alt_az, mname = comp.readMetricData(all_dict['Nvisits as function of Alt/Az night <= 365 all bands HealpixSlicer']['metricName'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 365 all bands HealpixSlicer']['metricMetadata'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 365 all bands HealpixSlicer']['slicerName'])

med_airmass_all, mname = comp.readMetricData(all_dict['Median airmass  night < 365 all bands HealpixSlicer']['metricName'],
                                             all_dict['Median airmass  night < 365 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Median airmass  night < 365 all bands HealpixSlicer']['slicerName'])

max_airmass_all, mname = comp.readMetricData(all_dict['Max airmass  night < 365 all bands HealpixSlicer']['metricName'],
                                             all_dict['Max airmass  night < 365 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Max airmass  night < 365 all bands HealpixSlicer']['slicerName'])

coaddM5_r, mname = comp.readMetricData(all_dict['CoaddM5  night < 365 r band HealpixSlicer']['metricName'],
                                       all_dict['CoaddM5  night < 365 r band HealpixSlicer']['metricMetadata'],
                                       all_dict['CoaddM5  night < 365 r band HealpixSlicer']['slicerName'])

with warnings.catch_warnings():
    comp.plotMetricData(n_visits_all,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'colorMin':0,'colorMax':150, 'xMin':60,'xMax':100},
                        outDir='.',savefig=True)
    comp.plotMetricData(n_visits_all_alt_az,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'xMin':60,'xMax':100,'rot': (90, 90, 90), 'flip': 'geo'},
                        outDir='.',savefig=True)
    comp.plotMetricData(med_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.02,'colorMax':1.31},outDir='.',savefig=True)
    comp.plotMetricData(max_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.1,'colorMax':2.5},outDir='.',savefig=True)
    comp.plotMetricData(coaddM5_r,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':-3.0,'colorMax':0.0},outDir='.',savefig=True)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
coaddM5rBundle = []
for r in runlist:
    coaddM5_r[r].setPlotDict({'color':colors[r],'label':r})
    coaddM5rBundle.append(coaddM5_r[r])
cm5r_ph = plots.PlotHandler()
cm5r_ph.setMetricBundles(coaddM5rBundle)

# %% [markdown]
# # CoaddM5 r band HealpixHistrogram

# %%
# comp.plotMetricData(coaddM5_r,
#                     plotFunc=plots.HealpixHistogram(),
#                     paramTitles=False,
#                     userPlotDict={'figsize':(8,8),'xMin':-0.65,'xMax':0.65,'zp':27.6},outDir='.',savefig=True)
cm5r_ph.plot(plots.HealpixHistogram(),
             plotDicts={'figsize':(8,8),'xMin':-6.0,'xMax':0.,'zp':27.6,'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distributions (OneDSlicer)

# %%
ha_hist_all, mname = comp.readMetricData(all_dict['HA Histogram  night < 365 all bands OneDSlicer']['metricName'],
                                         all_dict['HA Histogram  night < 365 all bands OneDSlicer']['metricMetadata'],
                                         all_dict['HA Histogram  night < 365 all bands OneDSlicer']['slicerName'])

# %%
ha_hist_y, mname = comp.readMetricData(all_dict['HA Histogram  night < 365 y band OneDSlicer']['metricName'],
                                       all_dict['HA Histogram  night < 365 y band OneDSlicer']['metricMetadata'],
                                       all_dict['HA Histogram  night < 365 y band OneDSlicer']['slicerName'])

# %%
HABundle = []
HABundle_y = []
for r in runlist:
    ha_hist_all[r].setPlotDict({'color':colors[r],'label':r})
    ha_hist_y[r].setPlotDict({'color':colors[r],'label':r})
    HABundle.append(ha_hist_all[r])
    HABundle_y.append(ha_hist_y[r])

# %%
ha_ph = plots.PlotHandler()
ha_ph.setMetricBundles(HABundle)

# %%
ha_ph_y = plots.PlotHandler()
ha_ph_y.setMetricBundles(HABundle_y)

# %% [markdown]
# # HA distribution all bands

# %%
ha_ph.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(6,6),'xMin':-6.0,'xMax':6.0,'yMax':12000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distribution y band

# %%
ha_ph_y.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(8,8),'xMin':-5.0,'xMax':5.0,'yMax':5000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # Slew time and distance distributions

# %%
slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Slew Time Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Time Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Distance Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_hist_bundle_list = []
zoom_slew_hist_bundle_list = []
slew_dist_bundle_list = []
zoom_slew_dist_bundle_list = []

# %%
for r in runlist:
    slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_hist_bundle_list.append(slew_time_hist[r])
    slew_dist_bundle_list.append(slew_dist_hist[r])
    zoom_slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_hist_bundle_list.append(zoom_slew_time_hist[r])
    zoom_slew_dist_bundle_list.append(zoom_slew_dist_hist[r])

# %%
ph_slewhist = plots.PlotHandler()
ph_slewdist = plots.PlotHandler()
zoom_ph_slewhist = plots.PlotHandler()
zoom_ph_slewdist = plots.PlotHandler()

# %%
ph_slewhist.setMetricBundles(slew_hist_bundle_list)
ph_slewdist.setMetricBundles(slew_dist_bundle_list)
zoom_ph_slewhist.setMetricBundles(zoom_slew_hist_bundle_list)
zoom_ph_slewdist.setMetricBundles(zoom_slew_dist_bundle_list)

# %%
ph_slewhist.plot(plots.OneDBinnedData(),
                       plotDicts={'figsize':(6,6),
                                  'xMin':-10,'xMax':150,
                                  'linewidth':2,'bins':np.arange(0,155,5)})
zoom_ph_slewhist.plot(plots.OneDBinnedData(),
                      plotDicts={'figsize':(6,6),
                                 'xMin':-1,'xMax':20,
                                 'linewidth':2,'bins':np.arange(0,155,5),'logScale':False})
# Out:
# 2

# %%
ph_slewdist.plot(plots.OneDBinnedData(),
                        plotDicts={'figsize':(6,6),'xMin':-10,
                                   'xMax':140,
                                   'linewidth':2,'bins':np.arange(0,155,1)})
zoom_ph_slewdist.plot(plots.OneDBinnedData(),
                     plotDicts={'figsize':(6,6),'xMin':-1,
                                'xMax':20,
                                'linewidth':2,'bins':np.arange(0,155,1),'logScale':False})
# Out:
# 2

# %%
comp.summaryStats.T.to_csv('baseline2018a_vs_colossus_2651_year1.csv')

# %%
cols = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list).T.columns.values

# %%
df_test = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list)

# %%
df_test['idx'] = cols

# %%
new_df = df_test[(df_test['idx'].str.contains('Max|Min|Sigma|Mean|Rms'))==False].round(3)

# %%
new_df[runlist]
# Out:
#                                                     baseline2018a  \
# Fraction of total Nvisits SouthCelestialPole ni...          0.002
# Fraction of total Nvisits WFD night <= 365                  0.083
# Fraction of total Nvisits GalacticPlane night <...          0.002
# Fraction of total Nvisits DD night <= 365                   0.004
# Fraction of total Nvisits NorthEclipticSpur nig...          0.005
# Fraction of total Nvisits DeepDrillingCosmology...          0.004
# Fraction of total Nvisits All props night <= 365            0.096
# Fraction of total Nvisits WideFastDeep night <=...          0.083
# Median NVisits WFD night < 365 all bands Healpi...         90.000
# Median NVisits WFD night < 365 g band HealpixSl...          6.000
# Median NVisits WFD night < 365 y band HealpixSl...         24.000
# Median NVisits WFD night < 365 z band HealpixSl...         28.000
# Median NVisits WFD night < 365 i band HealpixSl...         12.000
# Median NVisits WFD night < 365 r band HealpixSl...         16.000
# Median NVisits WFD night < 365 u band HealpixSl...          6.000
# Median CoaddM5 WFD night < 365 g band HealpixSl...         25.757
# Median CoaddM5 WFD night < 365 y band HealpixSl...         23.908
# Median CoaddM5 WFD night < 365 z band HealpixSl...         24.766
# Median CoaddM5 WFD night < 365 i band HealpixSl...         25.191
# Median CoaddM5 WFD night < 365 r band HealpixSl...         25.890
# Median CoaddM5 WFD night < 365 u band HealpixSl...         24.436
# Median Median seeingEff WFD night < 365 all ban...          0.780
# Median Median seeingEff WFD night < 365 g band ...          0.858
# Median Median seeingEff WFD night < 365 y band ...          0.753
# Median Median seeingEff WFD night < 365 z band ...          0.774
# Median Median seeingEff WFD night < 365 i band ...          0.764
# Median Median seeingEff WFD night < 365 r band ...          0.810
# Median Median seeingEff WFD night < 365 u band ...          0.844
# Median Median airmass WFD night < 365 all bands...          1.044
# Median Median airmass WFD night < 365 g band He...          1.046
# Median Median airmass WFD night < 365 y band He...          1.047
# Median Median airmass WFD night < 365 z band He...          1.057
# Median Median airmass WFD night < 365 i band He...          1.047
# Median Median airmass WFD night < 365 r band He...          1.044
# Median Median airmass WFD night < 365 u band He...          1.042
# Median slewTime All visits                                  5.300
# Filter Changes Whole Survey night <= 365                  758.000
# Filter Changes Per Night night <= 365 OneDSlicer          289.000
# Median Filter Changes Per Night night <= 365 On...          2.000
# Normalized Teff WFD night < 365 all bands                   0.734
# Median Normalized Teff WFD night < 365 all band...          0.731
# Normalized Teff WFD night < 365 all bands Healp...      21495.000
# Total Teff WFD night < 365 all bands                  4347843.312
# Total Teff  night < 365 all bands                     4784024.013
# OpenShutterFraction All visits night <= 365                 0.712
# Median OpenShutterFraction Per night night <= 3...          0.714
# OpenShutterFraction Per night night <= 365 OneD...        289.000
#
#                                                     colossus_2651
# Fraction of total Nvisits SouthCelestialPole ni...          0.038
# Fraction of total Nvisits WFD night <= 365                  0.826
# Fraction of total Nvisits GalacticPlane night <...          0.018
# Fraction of total Nvisits DD night <= 365                   0.067
# Fraction of total Nvisits NorthEclipticSpur nig...          0.050
# Fraction of total Nvisits DeepDrillingCosmology...          0.067
# Fraction of total Nvisits All props night <= 365            1.000
# Fraction of total Nvisits WideFastDeep night <=...          0.826
# Median NVisits WFD night < 365 all bands Healpi...         97.000
# Median NVisits WFD night < 365 g band HealpixSl...          6.000
# Median NVisits WFD night < 365 y band HealpixSl...         26.000
# Median NVisits WFD night < 365 z band HealpixSl...         19.000
# Median NVisits WFD night < 365 i band HealpixSl...         20.000
# Median NVisits WFD night < 365 r band HealpixSl...         19.000
# Median NVisits WFD night < 365 u band HealpixSl...          7.000
# Median CoaddM5 WFD night < 365 g band HealpixSl...         25.640
# Median CoaddM5 WFD night < 365 y band HealpixSl...         23.875
# Median CoaddM5 WFD night < 365 z band HealpixSl...         24.652
# Median CoaddM5 WFD night < 365 i band HealpixSl...         25.358
# Median CoaddM5 WFD night < 365 r band HealpixSl...         25.918
# Median CoaddM5 WFD night < 365 u band HealpixSl...         24.575
# Median Median seeingEff WFD night < 365 all ban...          0.784
# Median Median seeingEff WFD night < 365 g band ...          0.803
# Median Median seeingEff WFD night < 365 y band ...          0.766
# Median Median seeingEff WFD night < 365 z band ...          0.777
# Median Median seeingEff WFD night < 365 i band ...          0.794
# Median Median seeingEff WFD night < 365 r band ...          0.797
# Median Median seeingEff WFD night < 365 u band ...          0.817
# Median Median airmass WFD night < 365 all bands...          1.061
# Median Median airmass WFD night < 365 g band He...          1.056
# Median Median airmass WFD night < 365 y band He...          1.087
# Median Median airmass WFD night < 365 z band He...          1.062
# Median Median airmass WFD night < 365 i band He...          1.056
# Median Median airmass WFD night < 365 r band He...          1.056
# Median Median airmass WFD night < 365 u band He...          1.074
# Median slewTime All visits                                  5.119
# Filter Changes Whole Survey night <= 365                 1283.000
# Filter Changes Per Night night <= 365 OneDSlicer          289.000
# Median Filter Changes Per Night night <= 365 On...          2.000
# Normalized Teff WFD night < 365 all bands                   0.699
# Median Normalized Teff WFD night < 365 all band...          0.701
# Normalized Teff WFD night < 365 all bands Healp...      22618.000
# Total Teff WFD night < 365 all bands                  3857360.215
# Total Teff  night < 365 all bands                     4409311.994
# OpenShutterFraction All visits night <= 365                 0.694
# Median OpenShutterFraction Per night night <= 3...          0.696
# OpenShutterFraction Per night night <= 365 OneD...        289.000
