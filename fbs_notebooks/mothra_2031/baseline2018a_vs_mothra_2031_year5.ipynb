# %%
from __future__ import print_function
import lsst.sims.maf.plots as plots
import warnings
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import lsst.sims.maf.metricBundles as mb
import lsst.sims.maf.plots as plots
import lsst.sims.maf.runComparison as rc
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="505fd39d-37d3-4da5-9ad9-d09968321417">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Setup

# %%
colors = {'baseline2018a_5':'b','mothra_2031_5': 'r'}
runlist = list(colors.keys())

# %%
comp = rc.RunComparison(baseDir='.',runlist=runlist)

# %%
all_dict = comp.buildMetricDict(subdir='all05')

# %%
srd_dict = comp.buildMetricDict(subdir='srd05')

# %%
cadence_dict = comp.buildMetricDict(subdir='cadence05')

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(all_dict)

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(srd_dict)

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    comp.addSummaryStats(cadence_dict)

# %% [markdown]
# # fO summary metrics

# %%
comp.summaryStats.T.filter(like='fO',axis=0)
# Out:
#                                                     baseline2018a_5  \
# fOArea: Nvisits (#) fO WFD night < 1825 Healpix...       390.000000
# fOArea: Nvisits/benchmark fO WFD night < 1825 H...         0.472727
# fONv: Area (sqdeg) fO WFD night < 1825 HealpixS...      3355.495994
# fONv: Area/benchmark fO WFD night < 1825 Healpi...         0.186416
# fOArea: Nvisits (#) fO  night < 1825 HealpixSlicer       392.000000
# fOArea: Nvisits/benchmark fO  night < 1825 Heal...         0.475152
# fONv: Area (sqdeg) fO  night < 1825 HealpixSlicer       3399.978557
# fONv: Area/benchmark fO  night < 1825 HealpixSl...         0.188888
#
#                                                     mothra_2031_5
# fOArea: Nvisits (#) fO WFD night < 1825 Healpix...     251.000000
# fOArea: Nvisits/benchmark fO WFD night < 1825 H...       0.304242
# fONv: Area (sqdeg) fO WFD night < 1825 HealpixS...    -666.000000
# fONv: Area/benchmark fO WFD night < 1825 Healpi...    -666.000000
# fOArea: Nvisits (#) fO  night < 1825 HealpixSlicer     364.000000
# fOArea: Nvisits/benchmark fO  night < 1825 Heal...       0.441212
# fONv: Area (sqdeg) fO  night < 1825 HealpixSlicer       45.321857
# fONv: Area/benchmark fO  night < 1825 HealpixSl...       0.002518

# %% [markdown]
# # Rapid revist uniformity

# %%
comp.summaryStats.T.filter(like='RapidRevisitUniformity  night < 1825 HealpixSlicer',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Area (sq deg) RapidRevisitUniformity  night < 1...      3923.952341
# Max RapidRevisitUniformity  night < 1825 Healpi...         0.993289
# Mean RapidRevisitUniformity  night < 1825 Healp...         0.374351
# Median RapidRevisitUniformity  night < 1825 Hea...         0.372727
# Min RapidRevisitUniformity  night < 1825 Healpi...         0.075000
# N(+3Sigma) RapidRevisitUniformity  night < 1825...        83.000000
# N(-3Sigma) RapidRevisitUniformity  night < 1825...         0.000000
# RapidRevisitUniformity  night < 1825 HealpixSlicer     12826.000000
# Rms RapidRevisitUniformity  night < 1825 Healpi...         0.132523
#
#                                                     mothra_2031_5
# Area (sq deg) RapidRevisitUniformity  night < 1...     169.123423
# Max RapidRevisitUniformity  night < 1825 Healpi...       0.956174
# Mean RapidRevisitUniformity  night < 1825 Healp...       0.350746
# Median RapidRevisitUniformity  night < 1825 Hea...       0.346416
# Min RapidRevisitUniformity  night < 1825 Healpi...       0.156969
# N(+3Sigma) RapidRevisitUniformity  night < 1825...     101.000000
# N(-3Sigma) RapidRevisitUniformity  night < 1825...       0.000000
# RapidRevisitUniformity  night < 1825 HealpixSlicer   21953.000000
# Rms RapidRevisitUniformity  night < 1825 Healpi...       0.065601

# %% [markdown]
# # Rapid revist N

# %%
comp.summaryStats.T.filter(like='RapidRevisitN  night < 1825 HealpixSlicer',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Area (sq deg) RapidRevisitN  night < 1825 Healp...        86.175681
# Max RapidRevisitN  night < 1825 HealpixSlicer          12710.000000
# Mean RapidRevisitN  night < 1825 HealpixSlicer           155.163999
# Median RapidRevisitN  night < 1825 HealpixSlicer          94.000000
# Min RapidRevisitN  night < 1825 HealpixSlicer              0.000000
# N(+3Sigma) RapidRevisitN  night < 1825 HealpixS...        59.000000
# N(-3Sigma) RapidRevisitN  night < 1825 HealpixS...         0.000000
# RapidRevisitN  night < 1825 HealpixSlicer              31116.000000
# Rms RapidRevisitN  night < 1825 HealpixSlicer            459.192735
#
#                                                     mothra_2031_5
# Area (sq deg) RapidRevisitN  night < 1825 Healp...      70.142634
# Max RapidRevisitN  night < 1825 HealpixSlicer        15677.000000
# Mean RapidRevisitN  night < 1825 HealpixSlicer         187.736673
# Median RapidRevisitN  night < 1825 HealpixSlicer       194.000000
# Min RapidRevisitN  night < 1825 HealpixSlicer            0.000000
# N(+3Sigma) RapidRevisitN  night < 1825 HealpixS...      54.000000
# N(-3Sigma) RapidRevisitN  night < 1825 HealpixS...       0.000000
# RapidRevisitN  night < 1825 HealpixSlicer            31759.000000
# Rms RapidRevisitN  night < 1825 HealpixSlicer          537.417600

# %% [markdown]
# # Rapid revisit

# %%
comp.summaryStats.T.filter(like='RapidRevisits  night < 1825 HealpixSlicer',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Area (sq deg) RapidRevisits  night < 1825 Healp...      7791.607317
# Max RapidRevisits  night < 1825 HealpixSlicer              1.000000
# Mean RapidRevisits  night < 1825 HealpixSlicer             0.188874
# Median RapidRevisits  night < 1825 HealpixSlicer           0.000000
# Min RapidRevisits  night < 1825 HealpixSlicer              0.000000
# N(+3Sigma) RapidRevisits  night < 1825 HealpixS...         0.000000
# N(-3Sigma) RapidRevisits  night < 1825 HealpixS...         0.000000
# RapidRevisits  night < 1825 HealpixSlicer              31116.000000
# Rms RapidRevisits  night < 1825 HealpixSlicer              0.391408
#
#                                                     mothra_2031_5
# Area (sq deg) RapidRevisits  night < 1825 Healp...   28648.070165
# Max RapidRevisits  night < 1825 HealpixSlicer            1.000000
# Mean RapidRevisits  night < 1825 HealpixSlicer           0.694449
# Median RapidRevisits  night < 1825 HealpixSlicer         1.000000
# Min RapidRevisits  night < 1825 HealpixSlicer            0.000000
# N(+3Sigma) RapidRevisits  night < 1825 HealpixS...       0.000000
# N(-3Sigma) RapidRevisits  night < 1825 HealpixS...       0.000000
# RapidRevisits  night < 1825 HealpixSlicer            31759.000000
# Rms RapidRevisits  night < 1825 HealpixSlicer            0.460640

# %%
df_list = []

# %% [markdown]
# # Fraction in Pairs

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Fraction of visits in pairs',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Fraction of visits in pairs',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Median Fraction of visits in pairs (15-60 min) ...         0.910000
# Median Fraction of visits in pairs (15-60 min) ...         0.917391
#
#                                                     mothra_2031_5
# Median Fraction of visits in pairs (15-60 min) ...       0.900662
# Median Fraction of visits in pairs (15-60 min) ...       0.914634

# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format

# %%
nvists = comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
comp.summaryStats.T.filter(like='Nvisits All props',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Fraction of total Nvisits All props night <= 1825             0.499
# Nvisits All props night <= 1825                         1184315.000
# Max Nvisits All props night <= 1825 OneDSlicer             1082.000
# Mean Nvisits All props night <= 1825 OneDSlicer             787.443
# Median Nvisits All props night <= 1825 OneDSlicer           788.500
# Min Nvisits All props night <= 1825 OneDSlicer              142.000
# N(+3Sigma) Nvisits All props night <= 1825 OneD...            0.000
# N(-3Sigma) Nvisits All props night <= 1825 OneD...           17.000
# Nvisits All props night <= 1825 OneDSlicer                 1504.000
# Rms Nvisits All props night <= 1825 OneDSlicer              177.932
#
#                                                     mothra_2031_5
# Fraction of total Nvisits All props night <= 1825           0.880
# Nvisits All props night <= 1825                       1152392.000
# Max Nvisits All props night <= 1825 OneDSlicer           1057.000
# Mean Nvisits All props night <= 1825 OneDSlicer           766.218
# Median Nvisits All props night <= 1825 OneDSlicer         780.000
# Min Nvisits All props night <= 1825 OneDSlicer            140.000
# N(+3Sigma) Nvisits All props night <= 1825 OneD...          0.000
# N(-3Sigma) Nvisits All props night <= 1825 OneD...         31.000
# Nvisits All props night <= 1825 OneDSlicer               1504.000
# Rms Nvisits All props night <= 1825 OneDSlicer            165.912

# %% [markdown]
# # Fraction of Total visits per proposal

# %%
comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Fraction of total Nvisits GalacticPlane night <...            0.009
# Fraction of total Nvisits All props night <= 1825             0.499
# Fraction of total Nvisits WFD night <= 1825                   0.433
# Fraction of total Nvisits DD night <= 1825                    0.020
# Fraction of total Nvisits NorthEclipticSpur nig...            0.027
# Fraction of total Nvisits SouthCelestialPole ni...            0.011
# Fraction of total Nvisits DeepDrillingCosmology...            0.020
# Fraction of total Nvisits WideFastDeep night <=...            0.433
#
#                                                     mothra_2031_5
# Fraction of total Nvisits GalacticPlane night <...          0.015
# Fraction of total Nvisits All props night <= 1825           0.880
# Fraction of total Nvisits WFD night <= 1825                 0.752
# Fraction of total Nvisits DD night <= 1825                  0.048
# Fraction of total Nvisits NorthEclipticSpur nig...          0.041
# Fraction of total Nvisits SouthCelestialPole ni...          0.024
# Fraction of total Nvisits DeepDrillingCosmology...          0.048
# Fraction of total Nvisits WideFastDeep night <=...          0.752

# %% [markdown]
# # Median Nvsits per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median NVisits WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Median NVisits WFD night < 1825 y band HealpixS...           97.000
# Median NVisits WFD night < 1825 all bands Healp...          453.000
# Median NVisits WFD night < 1825 r band HealpixS...           96.000
# Median NVisits WFD night < 1825 u band HealpixS...           29.000
# Median NVisits WFD night < 1825 i band HealpixS...           94.000
# Median NVisits WFD night < 1825 z band HealpixS...           99.000
# Median NVisits WFD night < 1825 g band HealpixS...           42.000
#
#                                                     mothra_2031_5
# Median NVisits WFD night < 1825 y band HealpixS...        108.000
# Median NVisits WFD night < 1825 all bands Healp...        516.000
# Median NVisits WFD night < 1825 r band HealpixS...        109.000
# Median NVisits WFD night < 1825 u band HealpixS...         47.000
# Median NVisits WFD night < 1825 i band HealpixS...        110.000
# Median NVisits WFD night < 1825 z band HealpixS...         98.000
# Median NVisits WFD night < 1825 g band HealpixS...         45.000

# %% [markdown]
# # Median CoaddedM5 per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median CoaddM5 WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Median CoaddM5 WFD night < 1825 y band HealpixS...           24.580
# Median CoaddM5 WFD night < 1825 r band HealpixS...           26.819
# Median CoaddM5 WFD night < 1825 u band HealpixS...           25.230
# Median CoaddM5 WFD night < 1825 i band HealpixS...           26.228
# Median CoaddM5 WFD night < 1825 z band HealpixS...           25.400
# Median CoaddM5 WFD night < 1825 g band HealpixS...           26.741
#
#                                                     mothra_2031_5
# Median CoaddM5 WFD night < 1825 y band HealpixS...         24.659
# Median CoaddM5 WFD night < 1825 r band HealpixS...         26.712
# Median CoaddM5 WFD night < 1825 u band HealpixS...         25.495
# Median CoaddM5 WFD night < 1825 i band HealpixS...         26.218
# Median CoaddM5 WFD night < 1825 z band HealpixS...         25.576
# Median CoaddM5 WFD night < 1825 g band HealpixS...         26.598

# %% [markdown]
# # Median seeingEff per filter WFD

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median seeingEff WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Median Median seeingEff WFD night < 1825 y band...            0.795
# Median Median seeingEff WFD night < 1825 all ba...            0.824
# Median Median seeingEff WFD night < 1825 r band...            0.841
# Median Median seeingEff WFD night < 1825 u band...            0.951
# Median Median seeingEff WFD night < 1825 i band...            0.810
# Median Median seeingEff WFD night < 1825 z band...            0.805
# Median Median seeingEff WFD night < 1825 g band...            0.887
#
#                                                     mothra_2031_5
# Median Median seeingEff WFD night < 1825 y band...          0.777
# Median Median seeingEff WFD night < 1825 all ba...          0.821
# Median Median seeingEff WFD night < 1825 r band...          0.836
# Median Median seeingEff WFD night < 1825 u band...          0.935
# Median Median seeingEff WFD night < 1825 i band...          0.812
# Median Median seeingEff WFD night < 1825 z band...          0.800
# Median Median seeingEff WFD night < 1825 g band...          0.889

# %% [markdown]
# # Median airmass

# %%
df_list.append(comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna())
comp.summaryStats.T.filter(like='Median Median airmass WFD',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Median Median airmass WFD night < 1825 y band H...            1.069
# Median Median airmass WFD night < 1825 all band...            1.047
# Median Median airmass WFD night < 1825 r band H...            1.045
# Median Median airmass WFD night < 1825 u band H...            1.043
# Median Median airmass WFD night < 1825 i band H...            1.049
# Median Median airmass WFD night < 1825 z band H...            1.056
# Median Median airmass WFD night < 1825 g band H...            1.046
#
#                                                     mothra_2031_5
# Median Median airmass WFD night < 1825 y band H...          1.055
# Median Median airmass WFD night < 1825 all band...          1.050
# Median Median airmass WFD night < 1825 r band H...          1.049
# Median Median airmass WFD night < 1825 u band H...          1.058
# Median Median airmass WFD night < 1825 i band H...          1.048
# Median Median airmass WFD night < 1825 z band H...          1.048
# Median Median airmass WFD night < 1825 g band H...          1.051

# %% [markdown]
# # Slew statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='slew',axis=0).dropna())
comp.summaryStats.T.filter(like='slew',axis=0).dropna()
# Out:
#                                baseline2018a_5  mothra_2031_5
# Mean slewTime night <= 1825              8.101          9.323
# Median slewTime night <= 1825            5.209          5.323
# Min slewTime night <= 1825               2.000          2.000
# Max slewTime night <= 1825             143.000        140.000

# %%
comp.summaryStats.T.filter(like='Slew',axis=0).dropna()
# Out:
#                           baseline2018a_5  mothra_2031_5
# Slew Count night <= 1825      1184315.000    1152392.000

# %% [markdown]
# # Filter change statistics

# %%
df_list.append(comp.summaryStats.T.filter(like='Filter',axis=0).dropna())
comp.summaryStats.T.filter(like='Filter',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Filter Changes Whole Survey night <= 1825                  4850.000
# Filter Changes Per Night night <= 1825 OneDSlicer          1504.000
# Max Filter Changes Per Night night <= 1825 OneD...           23.000
# Mean Filter Changes Per Night night <= 1825 One...            2.852
# Median Filter Changes Per Night night <= 1825 O...            2.000
# Min Filter Changes Per Night night <= 1825 OneD...            0.000
# N(+3Sigma) Filter Changes Per Night night <= 18...           28.000
# N(-3Sigma) Filter Changes Per Night night <= 18...            0.000
# Rms Filter Changes Per Night night <= 1825 OneD...            3.192
#
#                                                     mothra_2031_5
# Filter Changes Whole Survey night <= 1825                5902.000
# Filter Changes Per Night night <= 1825 OneDSlicer        1504.000
# Max Filter Changes Per Night night <= 1825 OneD...          8.000
# Mean Filter Changes Per Night night <= 1825 One...          2.928
# Median Filter Changes Per Night night <= 1825 O...          2.000
# Min Filter Changes Per Night night <= 1825 OneD...          0.000
# N(+3Sigma) Filter Changes Per Night night <= 18...          0.000
# N(-3Sigma) Filter Changes Per Night night <= 18...          0.000
# Rms Filter Changes Per Night night <= 1825 OneD...          2.563

# %% [markdown]
# # Normalized effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Normalized Teff WFD night < 1825 all bands',axis=0).dropna())
comp.summaryStats.T.filter(like='Normalized Teff WFD night < 1825 all bands',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# Normalized Teff WFD night < 1825 all bands                    0.613
# Max Normalized Teff WFD night < 1825 all bands ...            0.786
# Mean Normalized Teff WFD night < 1825 all bands...            0.614
# Median Normalized Teff WFD night < 1825 all ban...            0.612
# Min Normalized Teff WFD night < 1825 all bands ...            0.424
# N(+3Sigma) Normalized Teff WFD night < 1825 all...            0.000
# N(-3Sigma) Normalized Teff WFD night < 1825 all...            0.000
# Normalized Teff WFD night < 1825 all bands Heal...        21495.000
# Rms Normalized Teff WFD night < 1825 all bands ...            0.077
#
#                                                     mothra_2031_5
# Normalized Teff WFD night < 1825 all bands                  0.606
# Max Normalized Teff WFD night < 1825 all bands ...          1.718
# Mean Normalized Teff WFD night < 1825 all bands...          0.603
# Median Normalized Teff WFD night < 1825 all ban...          0.618
# Min Normalized Teff WFD night < 1825 all bands ...          0.019
# N(+3Sigma) Normalized Teff WFD night < 1825 all...         52.000
# N(-3Sigma) Normalized Teff WFD night < 1825 all...        220.000
# Normalized Teff WFD night < 1825 all bands Heal...      22774.000
# Rms Normalized Teff WFD night < 1825 all bands ...          0.087

# %% [markdown]
# # Total effective time

# %%
df_list.append(comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna())
comp.summaryStats.T.filter(like='Total Teff',axis=0).dropna()
# Out:
#                                        baseline2018a_5  mothra_2031_5
# Total Teff  night < 1825 all bands        20855645.138   19922232.171
# Total Teff WFD night < 1825 all bands     18903034.919   17911040.301

# %% [markdown]
# # Open shutter fraction

# %%
df_list.append(comp.summaryStats.T.filter(like='Open',axis=0).dropna())
comp.summaryStats.T.filter(like='Open',axis=0).dropna()
# Out:
#                                                     baseline2018a_5  \
# OpenShutterFraction All visits night <= 1825                  0.713
# Max OpenShutterFraction Per night night <= 1825...            0.765
# Mean OpenShutterFraction Per night night <= 182...            0.712
# Median OpenShutterFraction Per night night <= 1...            0.714
# Min OpenShutterFraction Per night night <= 1825...            0.601
# N(+3Sigma) OpenShutterFraction Per night night ...            0.000
# N(-3Sigma) OpenShutterFraction Per night night ...           12.000
# OpenShutterFraction Per night night <= 1825 One...         1504.000
# Rms OpenShutterFraction Per night night <= 1825...            0.023
#
#                                                     mothra_2031_5
# OpenShutterFraction All visits night <= 1825                0.692
# Max OpenShutterFraction Per night night <= 1825...          0.753
# Mean OpenShutterFraction Per night night <= 182...          0.694
# Median OpenShutterFraction Per night night <= 1...          0.697
# Min OpenShutterFraction Per night night <= 1825...          0.601
# N(+3Sigma) OpenShutterFraction Per night night ...          0.000
# N(-3Sigma) OpenShutterFraction Per night night ...          2.000
# OpenShutterFraction Per night night <= 1825 One...       1504.000
# Rms OpenShutterFraction Per night night <= 1825...          0.029

# %% [markdown]
# # HealpixSkyMaps
#  - Nvisits all bands
#  - Nvisits alt/az all bands
#  - Median airmass all bands
#  - Max airmass all bands
#  - CoaddM5 r band

# %%
n_visits_all, mname = comp.readMetricData(all_dict['NVisits  night < 1825 all bands HealpixSlicer']['metricName'],
                                          all_dict['NVisits  night < 1825 all bands HealpixSlicer']['metricMetadata'],
                                          all_dict['NVisits  night < 1825 all bands HealpixSlicer']['slicerName'])

n_visits_all_alt_az, mname = comp.readMetricData(all_dict['Nvisits as function of Alt/Az night <= 1825 all bands HealpixSlicer']['metricName'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 1825 all bands HealpixSlicer']['metricMetadata'],
                                                 all_dict['Nvisits as function of Alt/Az night <= 1825 all bands HealpixSlicer']['slicerName'])

med_airmass_all, mname = comp.readMetricData(all_dict['Median airmass  night < 1825 all bands HealpixSlicer']['metricName'],
                                             all_dict['Median airmass  night < 1825 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Median airmass  night < 1825 all bands HealpixSlicer']['slicerName'])

max_airmass_all, mname = comp.readMetricData(all_dict['Max airmass  night < 1825 all bands HealpixSlicer']['metricName'],
                                             all_dict['Max airmass  night < 1825 all bands HealpixSlicer']['metricMetadata'],
                                             all_dict['Max airmass  night < 1825 all bands HealpixSlicer']['slicerName'])

coaddM5_r, mname = comp.readMetricData(all_dict['CoaddM5  night < 1825 r band HealpixSlicer']['metricName'],
                                       all_dict['CoaddM5  night < 1825 r band HealpixSlicer']['metricMetadata'],
                                       all_dict['CoaddM5  night < 1825 r band HealpixSlicer']['slicerName'])

with warnings.catch_warnings():
    comp.plotMetricData(n_visits_all,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'colorMin':0,'colorMax':450, 'xMin':60,'xMax':100},
                        outDir='.',savefig=True)
    comp.plotMetricData(n_visits_all_alt_az,
                        plotFunc=plots.HealpixSkyMap(),
                        userPlotDict={'figsize':(12,4),'xMin':60,'xMax':100,'rot': (90, 90, 90), 'flip': 'geo'},
                        outDir='.',savefig=True)
    comp.plotMetricData(med_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.02,'colorMax':1.31},outDir='.',savefig=True)
    comp.plotMetricData(max_airmass_all,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':1.1,'colorMax':2.5},outDir='.',savefig=True)
    comp.plotMetricData(coaddM5_r,
                        plotFunc=plots.HealpixSkyMap(),
                        paramTitles=False,
                        userPlotDict={'figsize':(12,4),'colorMin':-3.0,'colorMax':0.0},outDir='.',savefig=True)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/docmaf/stack/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
coaddM5rBundle = []
for r in runlist:
    coaddM5_r[r].setPlotDict({'color':colors[r],'label':r})
    coaddM5rBundle.append(coaddM5_r[r])
cm5r_ph = plots.PlotHandler()
cm5r_ph.setMetricBundles(coaddM5rBundle)

# %% [markdown]
# # CoaddM5 r band HealpixHistrogram

# %%
# comp.plotMetricData(coaddM5_r,
#                     plotFunc=plots.HealpixHistogram(),
#                     paramTitles=False,
#                     userPlotDict={'figsize':(8,8),'xMin':-0.65,'xMax':0.65,'zp':27.6},outDir='.',savefig=True)
cm5r_ph.plot(plots.HealpixHistogram(),
             plotDicts={'figsize':(8,8),'xMin':-6.0,'xMax':0.,'zp':27.6,'linewidth':3})
# Out:
# 1

# %% [markdown]
# # HA distributions (OneDSlicer)

# %%
ha_hist_all, mname = comp.readMetricData(all_dict['HA Histogram  night < 1825 all bands OneDSlicer']['metricName'],
                                         all_dict['HA Histogram  night < 1825 all bands OneDSlicer']['metricMetadata'],
                                         all_dict['HA Histogram  night < 1825 all bands OneDSlicer']['slicerName'])

# %%
ha_hist_y, mname = comp.readMetricData(all_dict['HA Histogram  night < 1825 y band OneDSlicer']['metricName'],
                                       all_dict['HA Histogram  night < 1825 y band OneDSlicer']['metricMetadata'],
                                       all_dict['HA Histogram  night < 1825 y band OneDSlicer']['slicerName'])

# %%
HABundle = []
HABundle_y = []
for r in runlist:
    ha_hist_all[r].setPlotDict({'color':colors[r],'label':'r','bins':np.arange(-10.0,10.1,1)})
    ha_hist_y[r].setPlotDict({'color':colors[r],'label':r})
    HABundle.append(ha_hist_all[r])
    HABundle_y.append(ha_hist_y[r])

# %%
ha_ph = plots.PlotHandler()
ha_ph.setMetricBundles(HABundle)

# %%
ha_ph_y = plots.PlotHandler()
ha_ph_y.setMetricBundles(HABundle_y)

# %% [markdown]
# # HA distribution all bands

# %%
fig = ha_ph.plot(plots.OneDBinnedData(),
                 plotDicts={'figsize':(6,6),'xMin':-5.5,'xMax':5.5,'yMax':52000,
                 'bins':np.arange(-10.0,10.1,1),'linewidth':3,
                 'logScale':False})
# plt.figure(fig)
# plt.axvline(x=3)
# plt.axvline(x=-3)
# plt.axvline(x=6)
# plt.axvline(x=-6)
# plt.savefig('log_ha_histogram_halimits.pdf')

# %% [markdown]
# # HA distribution y band

# %%
ha_ph_y.plot(plots.OneDBinnedData(),
           plotDicts={'figsize':(8,8),'xMin':-5.0,'xMax':5.0,'yMax':17000,'bins':np.arange(-6.0,6.1,0.1),'linewidth':3})
# Out:
# 1

# %% [markdown]
# # Slew time and distance distributions

# %%
slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Slew Time Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Time Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_time_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Time Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                           metricMetadata=all_dict['Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                           slicerName=all_dict['Slew Distance Histogram All visits OneDSlicer']['slicerName'])

zoom_slew_dist_hist,mname = comp.readMetricData(metricName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricName'],
                                                metricMetadata=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['metricMetadata'],
                                                slicerName=all_dict['Zoom Slew Distance Histogram All visits OneDSlicer']['slicerName'])

# %%
slew_hist_bundle_list = []
zoom_slew_hist_bundle_list = []
slew_dist_bundle_list = []
zoom_slew_dist_bundle_list = []

# %%
for r in runlist:
    slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    slew_hist_bundle_list.append(slew_time_hist[r])
    slew_dist_bundle_list.append(slew_dist_hist[r])
    zoom_slew_time_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_dist_hist[r].setPlotDict({'color':colors[r],'label':r})
    zoom_slew_hist_bundle_list.append(zoom_slew_time_hist[r])
    zoom_slew_dist_bundle_list.append(zoom_slew_dist_hist[r])

# %%
ph_slewhist = plots.PlotHandler()
ph_slewdist = plots.PlotHandler()
zoom_ph_slewhist = plots.PlotHandler()
zoom_ph_slewdist = plots.PlotHandler()

# %%
ph_slewhist.setMetricBundles(slew_hist_bundle_list)
ph_slewdist.setMetricBundles(slew_dist_bundle_list)
zoom_ph_slewhist.setMetricBundles(zoom_slew_hist_bundle_list)
zoom_ph_slewdist.setMetricBundles(zoom_slew_dist_bundle_list)

# %%
ph_slewhist.plot(plots.OneDBinnedData(),
                       plotDicts={'figsize':(6,6),
                                  'xMin':-10,'xMax':150,
                                  'linewidth':2,'bins':np.arange(0,155,5)})
zoom_ph_slewhist.plot(plots.OneDBinnedData(),
                      plotDicts={'figsize':(6,6),
                                 'xMin':-1,'xMax':20,'yMax':145000,
                                 'linewidth':2,'bins':np.arange(0,155,5),'logScale':False})
# Out:
# 2

# %%
ph_slewdist.plot(plots.OneDBinnedData(),
                        plotDicts={'figsize':(6,6),'xMin':-10,
                                   'xMax':140,
                                   'linewidth':2,'bins':np.arange(0,155,1)})
zoom_ph_slewdist.plot(plots.OneDBinnedData(),
                     plotDicts={'figsize':(6,6),'xMin':-1,
                                'xMax':10,'yMax':215000,
                                'linewidth':2,'bins':np.arange(0,155,1),'logScale':False})
# Out:
# 2

# %%
comp.summaryStats.T.to_csv('baseline2018a_vs_mothra_2031_year5.csv')

# %%
cols = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list).T.columns.values

# %%
df_test = comp.summaryStats.T.filter(like='Fraction of total',axis=0).dropna().append(df_list)

# %%
df_test['idx'] = cols

# %%
new_df = df_test[(df_test['idx'].str.contains('Max|Min|Sigma|Mean|Rms'))==False].round(3)

# %%
new_df[runlist]
# Out:
#                                                     baseline2018a_5  \
# Fraction of total Nvisits GalacticPlane night <...            0.009
# Fraction of total Nvisits All props night <= 1825             0.499
# Fraction of total Nvisits WFD night <= 1825                   0.433
# Fraction of total Nvisits DD night <= 1825                    0.020
# Fraction of total Nvisits NorthEclipticSpur nig...            0.027
# Fraction of total Nvisits SouthCelestialPole ni...            0.011
# Fraction of total Nvisits DeepDrillingCosmology...            0.020
# Fraction of total Nvisits WideFastDeep night <=...            0.433
# Median Fraction of visits in pairs (15-60 min) ...            0.910
# Median Fraction of visits in pairs (15-60 min) ...            0.917
# Median NVisits WFD night < 1825 y band HealpixS...           97.000
# Median NVisits WFD night < 1825 all bands Healp...          453.000
# Median NVisits WFD night < 1825 r band HealpixS...           96.000
# Median NVisits WFD night < 1825 u band HealpixS...           29.000
# Median NVisits WFD night < 1825 i band HealpixS...           94.000
# Median NVisits WFD night < 1825 z band HealpixS...           99.000
# Median NVisits WFD night < 1825 g band HealpixS...           42.000
# Median CoaddM5 WFD night < 1825 y band HealpixS...           24.580
# Median CoaddM5 WFD night < 1825 r band HealpixS...           26.819
# Median CoaddM5 WFD night < 1825 u band HealpixS...           25.230
# Median CoaddM5 WFD night < 1825 i band HealpixS...           26.228
# Median CoaddM5 WFD night < 1825 z band HealpixS...           25.400
# Median CoaddM5 WFD night < 1825 g band HealpixS...           26.741
# Median Median seeingEff WFD night < 1825 y band...            0.795
# Median Median seeingEff WFD night < 1825 all ba...            0.824
# Median Median seeingEff WFD night < 1825 r band...            0.841
# Median Median seeingEff WFD night < 1825 u band...            0.951
# Median Median seeingEff WFD night < 1825 i band...            0.810
# Median Median seeingEff WFD night < 1825 z band...            0.805
# Median Median seeingEff WFD night < 1825 g band...            0.887
# Median Median airmass WFD night < 1825 y band H...            1.069
# Median Median airmass WFD night < 1825 all band...            1.047
# Median Median airmass WFD night < 1825 r band H...            1.045
# Median Median airmass WFD night < 1825 u band H...            1.043
# Median Median airmass WFD night < 1825 i band H...            1.049
# Median Median airmass WFD night < 1825 z band H...            1.056
# Median Median airmass WFD night < 1825 g band H...            1.046
# Median slewTime night <= 1825                                 5.209
# Filter Changes Whole Survey night <= 1825                  4850.000
# Filter Changes Per Night night <= 1825 OneDSlicer          1504.000
# Median Filter Changes Per Night night <= 1825 O...            2.000
# Normalized Teff WFD night < 1825 all bands                    0.613
# Median Normalized Teff WFD night < 1825 all ban...            0.612
# Normalized Teff WFD night < 1825 all bands Heal...        21495.000
# Total Teff  night < 1825 all bands                     20855645.138
# Total Teff WFD night < 1825 all bands                  18903034.919
# OpenShutterFraction All visits night <= 1825                  0.713
# Median OpenShutterFraction Per night night <= 1...            0.714
# OpenShutterFraction Per night night <= 1825 One...         1504.000
#
#                                                     mothra_2031_5
# Fraction of total Nvisits GalacticPlane night <...          0.015
# Fraction of total Nvisits All props night <= 1825           0.880
# Fraction of total Nvisits WFD night <= 1825                 0.752
# Fraction of total Nvisits DD night <= 1825                  0.048
# Fraction of total Nvisits NorthEclipticSpur nig...          0.041
# Fraction of total Nvisits SouthCelestialPole ni...          0.024
# Fraction of total Nvisits DeepDrillingCosmology...          0.048
# Fraction of total Nvisits WideFastDeep night <=...          0.752
# Median Fraction of visits in pairs (15-60 min) ...          0.901
# Median Fraction of visits in pairs (15-60 min) ...          0.915
# Median NVisits WFD night < 1825 y band HealpixS...        108.000
# Median NVisits WFD night < 1825 all bands Healp...        516.000
# Median NVisits WFD night < 1825 r band HealpixS...        109.000
# Median NVisits WFD night < 1825 u band HealpixS...         47.000
# Median NVisits WFD night < 1825 i band HealpixS...        110.000
# Median NVisits WFD night < 1825 z band HealpixS...         98.000
# Median NVisits WFD night < 1825 g band HealpixS...         45.000
# Median CoaddM5 WFD night < 1825 y band HealpixS...         24.659
# Median CoaddM5 WFD night < 1825 r band HealpixS...         26.712
# Median CoaddM5 WFD night < 1825 u band HealpixS...         25.495
# Median CoaddM5 WFD night < 1825 i band HealpixS...         26.218
# Median CoaddM5 WFD night < 1825 z band HealpixS...         25.576
# Median CoaddM5 WFD night < 1825 g band HealpixS...         26.598
# Median Median seeingEff WFD night < 1825 y band...          0.777
# Median Median seeingEff WFD night < 1825 all ba...          0.821
# Median Median seeingEff WFD night < 1825 r band...          0.836
# Median Median seeingEff WFD night < 1825 u band...          0.935
# Median Median seeingEff WFD night < 1825 i band...          0.812
# Median Median seeingEff WFD night < 1825 z band...          0.800
# Median Median seeingEff WFD night < 1825 g band...          0.889
# Median Median airmass WFD night < 1825 y band H...          1.055
# Median Median airmass WFD night < 1825 all band...          1.050
# Median Median airmass WFD night < 1825 r band H...          1.049
# Median Median airmass WFD night < 1825 u band H...          1.058
# Median Median airmass WFD night < 1825 i band H...          1.048
# Median Median airmass WFD night < 1825 z band H...          1.048
# Median Median airmass WFD night < 1825 g band H...          1.051
# Median slewTime night <= 1825                               5.323
# Filter Changes Whole Survey night <= 1825                5902.000
# Filter Changes Per Night night <= 1825 OneDSlicer        1504.000
# Median Filter Changes Per Night night <= 1825 O...          2.000
# Normalized Teff WFD night < 1825 all bands                  0.606
# Median Normalized Teff WFD night < 1825 all ban...          0.618
# Normalized Teff WFD night < 1825 all bands Heal...      22774.000
# Total Teff  night < 1825 all bands                   19922232.171
# Total Teff WFD night < 1825 all bands                17911040.301
# OpenShutterFraction All visits night <= 1825                0.692
# Median OpenShutterFraction Per night night <= 1...          0.697
# OpenShutterFraction Per night night <= 1825 One...       1504.000
